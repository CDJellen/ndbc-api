# %%
import os
import sys

# %%
os.chdir("..")
sys.path.append(os.getcwd())

# %%
os.getcwd()
# Out:
# '/home/cjellen/sources/github/ndbc-api'

# %%
from ndbc_api import NdbcApi

# %%
api = NdbcApi()

# %%
api.stations()
# Out:
#    Station Hull No./Config and Location Location Lat/Long  \
# 0    41001      3D90 (SC) East Hatteras     34.70N 72.23W
# 1    41002    3DV33 (SC) South Hatteras     31.75N 74.93W
# 2    41004            3DV02 (SC) Edisto     32.50N 79.08W
# 3    41008         3D36 (SC) Grays Reef     31.40N 80.85W
# 4    41009          3D65 (SC) Canaveral     28.50N 80.18W
# ..     ...                          ...               ...
# 35   SRST2         (MA) Sabine Pass, Tx     29.68N 94.03W
# 36   STDM4       (SU) Stannard Rock, Mi     47.18N 87.22W
# 37   TPLM2        (MA) Thomas Point, Md     38.88N 76.43W
# 38   VENF1              (AR) Venice, Fl     27.07N 82.45W
# 39   WPOW1          (MA) West Point, Wa    47.65N 122.43W
#
#                 Wind Speed          Wind Direction      Sea Level Pressure  \
# 0   Sensor/system failure.  Sensor/system failure.  Sensor/system failure.
# 1                      100                     100                     100
# 2                      100                     100                     100
# 3                      100                     100                     100
# 4                      100                     100                     100
# ..                     ...                     ...                     ...
# 35                      99                      99                      99
# 36                     100                     100  Sensor/system failure.
# 37                      99                      99                      99
# 38                      99                      99                      99
# 39                     100                     100                     100
#
#                Wave Height         Dominant Period                Air Temp  \
# 0   Sensor/system failure.  Sensor/system failure.  Sensor/system failure.
# 1                      100                     100                     100
# 2                       98                      98                     100
# 3                      100                     100                     100
# 4                      100                     100                     100
# ..                     ...                     ...                     ...
# 35    No sensor installed.    No sensor installed.                      99
# 36    No sensor installed.    No sensor installed.  Sensor/system failure.
# 37    No sensor installed.    No sensor installed.                      99
# 38    No sensor installed.    No sensor installed.                      99
# 39    No sensor installed.    No sensor installed.                     100
#
#                 Water Temp               Dew Point  \
# 0   Sensor/system failure.  Sensor/system failure.
# 1                       99                     100
# 2                       98                     100
# 3                       99                      77
# 4                       99                     100
# ..                     ...                     ...
# 35    No sensor installed.  Sensor/system failure.
# 36    No sensor installed.  Sensor/system failure.
# 37  Sensor/system failure.  Sensor/system failure.
# 38                      99                      99
# 39    No sensor installed.                     100
#
#                                                Remark
# 0                      Transmissions ceased 12/18/23.
# 1                                                 NaN
# 2                                                 NaN
# 3             All data is intermittent after 8/18/23.
# 4   Water temperature ceased 3/25/23. Air temperat...
# ..                                                ...
# 35  Dewpoint intermittent due to frequent supersat...
# 36  Barometric pressure failed 7/1/20. Air tempera...
# 37  Water temperature sensor removed 07/14/22. Dew...
# 38                                                NaN
# 39                                                NaN
#
# [146 rows x 12 columns]

# %%
api.get_modes()
# Out:
# ['adcp',
#  'cwind',
#  'ocean',
#  'spec',
#  'stdmet',
#  'supl',
#  'swden',
#  'swdir',
#  'swdir2',
#  'swr1',
#  'swr2']

# %%
df_stdmet_tplm2 = api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2022-01-01',
    as_df=True
)

# %%
df_stdmet_tplm2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17280 entries, 2020-01-01 00:00:00 to 2022-01-01 00:00:00
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WDIR    17255 non-null  float64
#  1   WSPD    17280 non-null  float64
#  2   GST     17280 non-null  float64
#  3   WVHT    0 non-null      float64
#  4   DPD     0 non-null      float64
#  5   APD     0 non-null      float64
#  6   MWD     0 non-null      float64
#  7   PRES    17278 non-null  float64
#  8   ATMP    17278 non-null  float64
#  9   WTMP    17280 non-null  float64
#  10  DEWP    14715 non-null  float64
#  11  VIS     0 non-null      float64
#  12  TIDE    0 non-null      float64
# dtypes: float64(13)
# memory usage: 1.8 MB

# %%
df_stdmet_tplm2.head(3).T
# Out:
# timestamp  2020-01-01 00:00:00  2020-01-01 01:00:00  2020-01-01 02:00:00
# WDIR                     188.0                273.0                286.0
# WSPD                       6.1                  6.0                  4.7
# GST                        6.2                  6.9                  5.6
# WVHT                       NaN                  NaN                  NaN
# DPD                        NaN                  NaN                  NaN
# APD                        NaN                  NaN                  NaN
# MWD                        NaN                  NaN                  NaN
# PRES                    1006.1               1006.8               1007.3
# ATMP                       9.5                  9.3                  8.7
# WTMP                       6.6                  6.6                  6.5
# DEWP                      -0.3                 -0.6                 -1.4
# VIS                        NaN                  NaN                  NaN
# TIDE                       NaN                  NaN                  NaN
