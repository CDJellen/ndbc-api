# %% [markdown]
# <div align="center">
#     <h3>A Python API for the National Data Buoy Center</h3>
# </div>
#
#
# The National Oceanic and Atmospheric Association's National Data Buoy Center maintains marine monitoring and observation stations around the world[^1]. These stations report atmospheric, oceanographic, and other meterological data at regular intervals to the NDBC. Measurements are made available over HTTP through the NDBC's data service.
#
# The ndbc-api is a python library that makes this data more widely accessible.
#
# The ndbc-api is primarily built to parse whitespace-delimited oceanographic and atmospheric data distributed as text files for available time ranges, on a station-by-station basis[^2]. Measurements are typically distributed as `utf-8` encoded, station-by-station, fixed-period text files. More information on the measurements and methodology are available [on the NDBC website](https://www.ndbc.noaa.gov/docs/ndbc_web_data_guide.pdf)[^3].
#
# [^1]: https://www.ndbc.noaa.gov/
# [^2]: https://www.ndbc.noaa.gov/obs.shtml
# [^3]: https://www.ndbc.noaa.gov/docs/ndbc_web_data_guide.pdf

# %% [markdown]
# This sample notebook covers some of the core functionality of the `NdbcApi`, including usage examples for retrieving the list of stations, station metadata, station measurements, and finding the nearest station to a given location.
#
# We assume some familiarity with NDBC data buoy's, their purpose, and their data formats, but the examples help provide extra context for users new to the NDBC data service.  One important feature to consider is that not all data buoys are alike.  Some buoys provide a full suite of measurements, while others provide only a subset.  The `NdbcApi` provides methods to help users determine which measurements are available for a given station, and to retrieve those measurements.

# %% [markdown]
# ### Setup

# %% [markdown]
# These setup steps are useful when cloning the project from source and running the notebooks locally.  If you are running the notebooks in a cloud environment, you can skip these steps and just run the cells under the "API Overview" heading.

# %%
import os
import sys

# %%
os.chdir("..")
sys.path.append(os.getcwd())

# %% [markdown]
# ### API Overview

# %% [markdown]
# The API surface is exposed through the `NdbcApi` class.  The `NdbcApi` is a singleton, such that the underlying `RequestHandler` and NDBC station-level `RequestCache`s are shared between instances. Both the singleton metaclass and `RequestHandler` are implemented to reduce the likelihood of repeat requests to the NDBC's data service, and to converse NDBC resources. This is balanced by a station-level `cache_limit`, implemented as an LRU cache, which seeks to balance a respect for user resources and NDBC resources.

# %%
from ndbc_api import NdbcApi

# %%
api = NdbcApi()

# %% [markdown]
# #### Obtain a list of NDBC-maintained stations (data buoys)

# %% [markdown]
# Now that we have our `api` instance, we can begin to obtain information from the NDBC data service.
#
# We begin by retrieving a list of all data buoys, and some of their high-level metadata.

# %%
api.stations()
# Out:
#    Station Hull No./Config and Location Location Lat/Long Wind Speed  \
# 0    41001      3D90 (SC) East Hatteras     34.70N 72.23W         99
# 1    41002    3DV33 (SC) South Hatteras     31.75N 74.93W         99
# 2    41004            3DV02 (SC) Edisto     32.50N 79.08W         99
# 3    41008         3D36 (SC) Grays Reef     31.40N 80.85W         99
# 4    41009          3D65 (SC) Canaveral     28.50N 80.18W         99
# ..     ...                          ...               ...        ...
# 35   SRST2         (MA) Sabine Pass, Tx     29.68N 94.03W         72
# 36   STDM4       (SU) Stannard Rock, Mi     47.18N 87.22W        100
# 37   TPLM2        (MA) Thomas Point, Md     38.88N 76.43W         99
# 38   VENF1              (AR) Venice, Fl     27.07N 82.45W        100
# 39   WPOW1          (MA) West Point, Wa    47.65N 122.43W         99
#
#    Wind Direction      Sea Level Pressure           Wave Height  \
# 0              99                      99                    99
# 1              99                      99                    99
# 2              99                      99                    99
# 3              99                      99                    99
# 4              99                      99                    99
# ..            ...                     ...                   ...
# 35             72                      72  No sensor installed.
# 36            100  Sensor/system failure.  No sensor installed.
# 37             99                      99  No sensor installed.
# 38            100                     100  No sensor installed.
# 39             99                      99  No sensor installed.
#
#          Dominant Period                Air Temp              Water Temp  \
# 0                     99                      99                      96
# 1                     99                      99                      91
# 2                     99                      99                      96
# 3                     99                      99                      92
# 4                     99                      99                      91
# ..                   ...                     ...                     ...
# 35  No sensor installed.                      72    No sensor installed.
# 36  No sensor installed.  Sensor/system failure.    No sensor installed.
# 37  No sensor installed.                      99  Sensor/system failure.
# 38  No sensor installed.                     100                     100
# 39  No sensor installed.                      99    No sensor installed.
#
#                  Dew Point                                             Remark
# 0                       99                                                NaN
# 1                       99                                                NaN
# 2                       99                                                NaN
# 3                       99  Dewpoint data failed 8/02/21. Air temp failed ...
# 4                       99  Air temperature and dewpoint data failed 11/10...
# ..                     ...                                                ...
# 35  Sensor/system failure.  System transmissions are intermittent 4/9/19. ...
# 36  Sensor/system failure.  Air temperature and dewpoint data failed 05/27...
# 37  Sensor/system failure.  Water temperature sensor removed 07/14/22. Dew...
# 38                     100                                                NaN
# 39                      99                                                NaN
#
# [146 rows x 12 columns]

# %% [markdown]
# It is important to note that the list of data buoys above is not exhaustive. The NDBC maintains a list of all active buoys [here](https://www.ndbc.noaa.gov/activestations.xml). The `get_stations` method returns a list of all active buoys maintained by the NDBC.
#
# There are additional buoys which are supported by other programs and feed in to the NDBC data service. As such, they should be supported. For an example, consider station id `APAM2`, which is maintained by the National Ocean Service, but is available under the `NdbcApi`'s `get_data` method. If you would like to see a buoy or buoy family added to the API, please open an issue on the [GitHub repository](https:///www.github.com/cdjellen//ndbc-api).

# %% [markdown]
# #### Check the API's supported data formats

# %% [markdown]
# The `NbdcApi` seeks to enable easy access to data from most common models of data buoy and oceanographic station.
#
# Data are assumed to follow common patterns based on the measurement type and the station type.  For example, a buoy that measures wind speed and direction will have a `cwind` mode, and a coastal station that measures wind speed and direction will have a `stdmet` mode.  The `NbdcApi` provides a `get_modes` method to list the available modes for a given station, and a `get_data` method to retrieve data for a given station and mode.
#
# Not all stations have support for all modes.

# %%
api.get_modes()
# Out:
# ['adcp',
#  'cwind',
#  'ocean',
#  'spec',
#  'stdmet',
#  'supl',
#  'swden',
#  'swdir',
#  'swdir2',
#  'swr1',
#  'swr2']

# %% [markdown]
# #### Find the nearest station to a location

# %% [markdown]
# In some cases, we might be interested in obtaining data from a location without a-priori knowledge of which data buoys or oceanography stations are nearby.  We can use the `get_nearest_stations` function to find the nearest stations to a given location.  This function returns the `station_id` of the nearest station to any given lat-lon location.
#
# It is important to check the metadata for that station to ensure it is close enough to meet your needs.

# %%
api.nearest_station(lat="38.88N", lon="76.43W")
# Out:
# 'TPLM2'

# %% [markdown]
# We can also search for a station from floating-point longitude and latitude values.

# %%
api.nearest_station(lat=38.88, lon=76.43)
# Out:
# 'TPLM2'

# %% [markdown]
# #### Obtain that station's metadata

# %% [markdown]
# The NDBC records some features of data buoys and oceanographic stations such as the location, station type, and elevations of various instruments.
#
# Using the `station_id` obtained above, we can query the NDBC data service for some additional details about the nearest station to `lat='38.88N', lon='76.43W'`.  This is both to verify that the nearest station is indeed close to our desired location, and to learn more about how measurements of interest are collected.

# %%
api.station(station_id="tplm2")
# Out:
# {'Sea temp depth': '1 m below MLLW',
#  'Barometer elevation': '12.2 m above mean sea level',
#  'Anemometer height': '18 m above site elevation',
#  'Air temp height': '17.4 m above site elevation',
#  'Site elevation': '0 m above mean sea level',
#  'Location': '38.899 N 76.436 W (38°53\'56" N 76°26\'9" W)',
#  'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, MARS payload',
#  'Name': 'Station TPLM2  - Thomas Point, MD'}

# %% [markdown]
# We can also obtain this metadata as a pandas DataFrame.

# %%
api.station(station_id="tplm2", as_df=True)
# Out:
#                                                                      0
# Sea temp depth                                          1 m below MLLW
# Barometer elevation                        12.2 m above mean sea level
# Anemometer height                            18 m above site elevation
# Air temp height                            17.4 m above site elevation
# Site elevation                                0 m above mean sea level
# Location                    38.899 N 76.436 W (38°53'56" N 76°26'9" W)
# Statation Type       Owned and maintained by National Data Buoy Cen...
# Name                                 Station TPLM2  - Thomas Point, MD

# %% [markdown]
# While this information provides some helpful context about the station, it does not tell us what measurements are actually collected at the station.  We learned that it is a C-MAN station, and that it is maintained by the NDBC.  In order to determine what realtime and historical measurements are available for query, we can make two additional API calls.

# %% [markdown]
# #### Obtain the realtime measurements available at that station

# %% [markdown]
# Each station, due to the variety of buoy designs and environmental factors, offers a potentially different set of available measurements.  In order to determine what realtime measurements are available for a specific station, we can use the `available_realtime` API method.

# %%
api.available_realtime(station_id="tplm2")
# Out:
# {'Real time hourly standard meteorological': {'data directory': 'https://www.ndbc.noaa.gov/data/hourly2/',
#   'description': 'https://www.ndbc.noaa.gov/faq/measdes.shtml#cwind'},
#  'Real time standard meteorological data': {'Real time standard meteorological data': 'https://www.ndbc.noaa.gov/data/realtime2/TPLM2.txt',
#   'description': 'https://www.ndbc.noaa.gov/faq/measdes.shtml#stdmet'},
#  'Real time continuous winds data': {'Real time continuous winds data': 'https://www.ndbc.noaa.gov/data/realtime2/TPLM2.cwind',
#   'description': 'https://www.ndbc.noaa.gov/faq/measdes.shtml#cwind'},
#  'Real time derived measurements data': {'Real time derived measurements data': 'https://www.ndbc.noaa.gov/data/derived2/TPLM2.dmv',
#   'description': 'https://www.ndbc.noaa.gov/faq/measdes.shtml#deriv'}}

# %% [markdown]
# We can also return this data as a pandas DataFrame.

# %%
api.available_realtime(station_id="tplm2", as_df=True)
# Out:
#                                                                    data directory  \
# Real time hourly standard meteorological  https://www.ndbc.noaa.gov/data/hourly2/
# Real time standard meteorological data                                        NaN
# Real time continuous winds data                                               NaN
# Real time derived measurements data                                           NaN
#
#                                                                                 description  \
# Real time hourly standard meteorological  https://www.ndbc.noaa.gov/faq/measdes.shtml#cwind
# Real time standard meteorological data    https://www.ndbc.noaa.gov/faq/measdes.shtml#st...
# Real time continuous winds data           https://www.ndbc.noaa.gov/faq/measdes.shtml#cwind
# Real time derived measurements data       https://www.ndbc.noaa.gov/faq/measdes.shtml#deriv
#
#                                                      Real time standard meteorological data  \
# Real time hourly standard meteorological                                                NaN
# Real time standard meteorological data    https://www.ndbc.noaa.gov/data/realtime2/TPLM2...
# Real time continuous winds data                                                         NaN
# Real time derived measurements data                                                     NaN
#
#                                                             Real time continuous winds data  \
# Real time hourly standard meteorological                                                NaN
# Real time standard meteorological data                                                  NaN
# Real time continuous winds data           https://www.ndbc.noaa.gov/data/realtime2/TPLM2...
# Real time derived measurements data                                                     NaN
#
#                                                         Real time derived measurements data
# Real time hourly standard meteorological                                                NaN
# Real time standard meteorological data                                                  NaN
# Real time continuous winds data                                                         NaN
# Real time derived measurements data       https://www.ndbc.noaa.gov/data/derived2/TPLM2.dmv

# %% [markdown]
# #### Determine what historical measurements are available at that station

# %% [markdown]
# We follow a similar process to determine what historical data is available at our station of interest, this time calling the `available_historical` method.

# %%
api.available_historical(station_id="tplm2")
# Out:
# {'Standard meteorological data': {'Jan 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm212023.txt.gz&dir=data/stdmet/Jan/',
#   'Feb 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm222023.txt.gz&dir=data/stdmet/Feb/',
#   'Mar 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm232023.txt.gz&dir=data/stdmet/Mar/',
#   'Apr 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm242023.txt.gz&dir=data/stdmet/Apr/',
#   'May 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm252023.txt.gz&dir=data/stdmet/May/',
#   'Jun 2023': 'https://www.ndbc.noaa.gov/data/stdmet/Jun/tplm2.txt',
#   '1985': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1985.txt.gz&dir=data/historical/stdmet/',
#   '1986': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1986.txt.gz&dir=data/historical/stdmet/',
#   '1987': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1987.txt.gz&dir=data/historical/stdmet/',
#   '1988': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1988.txt.gz&dir=data/historical/stdmet/',
#   '1989': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1989.txt.gz&dir=data/historical/stdmet/',
#   '1990': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1990.txt.gz&dir=data/historical/stdmet/',
#   '1991': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1991.txt.gz&dir=data/historical/stdmet/',
#   '1992': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1992.txt.gz&dir=data/historical/stdmet/',
#   '1993': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1993.txt.gz&dir=data/historical/stdmet/',
#   '1994': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1994.txt.gz&dir=data/historical/stdmet/',
#   '1995': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1995.txt.gz&dir=data/historical/stdmet/',
#   '1996': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1996.txt.gz&dir=data/historical/stdmet/',
#   '1997': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1997.txt.gz&dir=data/historical/stdmet/',
#   '1998': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1998.txt.gz&dir=data/historical/stdmet/',
#   '1999': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h1999.txt.gz&dir=data/historical/stdmet/',
#   '2000': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2000.txt.gz&dir=data/historical/stdmet/',
#   '2001': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2001.txt.gz&dir=data/historical/stdmet/',
#   '2002': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2002.txt.gz&dir=data/historical/stdmet/',
#   '2003': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2003.txt.gz&dir=data/historical/stdmet/',
#   '2004': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2004.txt.gz&dir=data/historical/stdmet/',
#   '2005': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2005.txt.gz&dir=data/historical/stdmet/',
#   '2006': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2006.txt.gz&dir=data/historical/stdmet/',
#   '2007': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2007.txt.gz&dir=data/historical/stdmet/',
#   '2008': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2008.txt.gz&dir=data/historical/stdmet/',
#   '2009': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2009.txt.gz&dir=data/historical/stdmet/',
#   '2010': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2010.txt.gz&dir=data/historical/stdmet/',
#   '2011': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2011.txt.gz&dir=data/historical/stdmet/',
#   '2012': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2012.txt.gz&dir=data/historical/stdmet/',
#   '2013': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2013.txt.gz&dir=data/historical/stdmet/',
#   '2014': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2014.txt.gz&dir=data/historical/stdmet/',
#   '2015': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2015.txt.gz&dir=data/historical/stdmet/',
#   '2016': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2016.txt.gz&dir=data/historical/stdmet/',
#   '2017': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2017.txt.gz&dir=data/historical/stdmet/',
#   '2018': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2018.txt.gz&dir=data/historical/stdmet/',
#   '2019': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2019.txt.gz&dir=data/historical/stdmet/',
#   '2020': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2020.txt.gz&dir=data/historical/stdmet/',
#   '2021': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2021.txt.gz&dir=data/historical/stdmet/',
#   '2022': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2h2022.txt.gz&dir=data/historical/stdmet/'},
#  'Continuous winds data': {'Jan 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm212023.txt.gz&dir=data/cwind/Jan/',
#   'Feb 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm222023.txt.gz&dir=data/cwind/Feb/',
#   'Mar 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm232023.txt.gz&dir=data/cwind/Mar/',
#   'Apr 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm242023.txt.gz&dir=data/cwind/Apr/',
#   'May 2023': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm252023.txt.gz&dir=data/cwind/May/',
#   'Jun 2023': 'https://www.ndbc.noaa.gov/data/cwind/Jun/tplm2.txt',
#   '1990': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1990.txt.gz&dir=data/historical/cwind/',
#   '1991': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1991.txt.gz&dir=data/historical/cwind/',
#   '1992': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1992.txt.gz&dir=data/historical/cwind/',
#   '1993': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1993.txt.gz&dir=data/historical/cwind/',
#   '1996': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1996.txt.gz&dir=data/historical/cwind/',
#   '1997': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1997.txt.gz&dir=data/historical/cwind/',
#   '1998': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1998.txt.gz&dir=data/historical/cwind/',
#   '1999': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c1999.txt.gz&dir=data/historical/cwind/',
#   '2000': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2000.txt.gz&dir=data/historical/cwind/',
#   '2001': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2001.txt.gz&dir=data/historical/cwind/',
#   '2002': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2002.txt.gz&dir=data/historical/cwind/',
#   '2003': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2003.txt.gz&dir=data/historical/cwind/',
#   '2004': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2004.txt.gz&dir=data/historical/cwind/',
#   '2005': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2005.txt.gz&dir=data/historical/cwind/',
#   '2006': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2006.txt.gz&dir=data/historical/cwind/',
#   '2007': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2007.txt.gz&dir=data/historical/cwind/',
#   '2008': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2008.txt.gz&dir=data/historical/cwind/',
#   '2009': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2009.txt.gz&dir=data/historical/cwind/',
#   '2010': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2010.txt.gz&dir=data/historical/cwind/',
#   '2011': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2011.txt.gz&dir=data/historical/cwind/',
#   '2012': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2012.txt.gz&dir=data/historical/cwind/',
#   '2013': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2013.txt.gz&dir=data/historical/cwind/',
#   '2014': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2014.txt.gz&dir=data/historical/cwind/',
#   '2015': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2015.txt.gz&dir=data/historical/cwind/',
#   '2016': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2016.txt.gz&dir=data/historical/cwind/',
#   '2017': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2017.txt.gz&dir=data/historical/cwind/',
#   '2018': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2018.txt.gz&dir=data/historical/cwind/',
#   '2019': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2019.txt.gz&dir=data/historical/cwind/',
#   '2020': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2020.txt.gz&dir=data/historical/cwind/',
#   '2021': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2021.txt.gz&dir=data/historical/cwind/',
#   '2022': 'https://www.ndbc.noaa.gov/download_data.php?filename=tplm2c2022.txt.gz&dir=data/historical/cwind/'}}

# %% [markdown]
# Again, we could also capture this data as a pandas DataFrame.

# %%
api.available_historical(station_id="tplm2", as_df=True)
# Out:
#                                                                        Jan 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                        Feb 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                        Mar 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                        Apr 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                        May 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                        Jun 2023  \
# Standard meteorological data  https://www.ndbc.noaa.gov/data/stdmet/Jun/tplm...
# Continuous winds data         https://www.ndbc.noaa.gov/data/cwind/Jun/tplm2...
#
#                                                                            1985  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data                                                       NaN
#
#                                                                            1986  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data                                                       NaN
#
#                                                                            1987  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data                                                       NaN
#
#                                                                            1988  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data                                                       NaN
#
#                               ...  \
# Standard meteorological data  ...
# Continuous winds data         ...
#
#                                                                            2013  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2014  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2015  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2016  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2017  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2018  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2019  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2020  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2021  \
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
#                                                                            2022
# Standard meteorological data  https://www.ndbc.noaa.gov/download_data.php?fi...
# Continuous winds data         https://www.ndbc.noaa.gov/download_data.php?fi...
#
# [2 rows x 44 columns]

# %% [markdown]
# #### Obtain measurements over a given time range

# %% [markdown]
# Now that we know both `stdmet` (Standard Meterological) and `cwind` (Continuous Winds) data are available for our station, we can begin to obtain these measurements using our API.
#
# We can select any time range of interest, regardless of the 45-day limit for "realtime" data before it becomes "historical" data.  The API abstracts these concerns away, and will automatically retrieve the data from the appropriate source, unifying it into a single `pd.DataFrame` or `dict` object.

# %% [markdown]
# We can begin by querying all `stdmet` data for our station `'tplm2'` for calendar-year 2020.  These dates follow the time conventions of the NDBC data service.

# %%
df_stdmet_tplm2 = api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2022-01-01',
    as_df=True
)

# %% [markdown]
# By inspecting the returned `pd.DataFrame`, we can see that some of the typical `stdmet` feautures are unavailable for this station.  If we were to pull this data directly from the NDBC data service, these missing measurements would be marked with `99.0` `999` or `999.0` values (depending on the measurement).  However, the `stdmet` data service replaces these values with `NaN` values.  This is done to make it easier to work with the data in downstream applications and analyses.

# %%
df_stdmet_tplm2.head(3).T
# Out:
# timestamp  2020-01-01 00:00:00  2020-01-01 01:00:00  2020-01-01 02:00:00
# WDIR                     188.0                273.0                286.0
# WSPD                       6.1                  6.0                  4.7
# GST                        6.2                  6.9                  5.6
# WVHT                       NaN                  NaN                  NaN
# DPD                        NaN                  NaN                  NaN
# APD                        NaN                  NaN                  NaN
# MWD                        NaN                  NaN                  NaN
# PRES                    1006.1               1006.8               1007.3
# ATMP                       9.5                  9.3                  8.7
# WTMP                       6.6                  6.6                  6.5
# DEWP                      -0.3                 -0.6                 -1.4
# VIS                        NaN                  NaN                  NaN
# TIDE                       NaN                  NaN                  NaN

# %%
df_stdmet_tplm2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17280 entries, 2020-01-01 00:00:00 to 2022-01-01 00:00:00
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WDIR    17255 non-null  float64
#  1   WSPD    17280 non-null  float64
#  2   GST     17280 non-null  float64
#  3   WVHT    0 non-null      float64
#  4   DPD     0 non-null      float64
#  5   APD     0 non-null      float64
#  6   MWD     0 non-null      float64
#  7   PRES    17278 non-null  float64
#  8   ATMP    17278 non-null  float64
#  9   WTMP    17280 non-null  float64
#  10  DEWP    14715 non-null  float64
#  11  VIS     0 non-null      float64
#  12  TIDE    0 non-null      float64
# dtypes: float64(13)
# memory usage: 1.8 MB

# %% [markdown]
# In the informational view above, note that we have indexed the data by its `timestamp`, which was computed using the `'YY'`, `'MM'`, `'DD'`, `'hh'`, and `'mm'` fields typical of the NDBC data service.

# %% [markdown]
# We can also capture this data as a basic python `dict` object, which can be used to create other data structures or serialized for outside analysis or tools.

# %%
api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2020-01-02',
    as_df=False
)
# Out:
# {'WDIR': {Timestamp('2020-01-01 00:00:00'): 188.0,
#   Timestamp('2020-01-01 01:00:00'): 273.0,
#   Timestamp('2020-01-01 02:00:00'): 286.0,
#   Timestamp('2020-01-01 03:00:00'): 278.0,
#   Timestamp('2020-01-01 04:00:00'): 293.0,
#   Timestamp('2020-01-01 05:00:00'): 297.0,
#   Timestamp('2020-01-01 06:00:00'): 296.0,
#   Timestamp('2020-01-01 07:00:00'): 287.0,
#   Timestamp('2020-01-01 08:00:00'): 287.0,
#   Timestamp('2020-01-01 09:00:00'): 282.0,
#   Timestamp('2020-01-01 10:00:00'): 286.0,
#   Timestamp('2020-01-01 11:00:00'): 276.0,
#   Timestamp('2020-01-01 12:00:00'): 271.0,
#   Timestamp('2020-01-01 13:00:00'): 275.0,
#   Timestamp('2020-01-01 14:00:00'): 266.0,
#   Timestamp('2020-01-01 15:00:00'): 269.0,
#   Timestamp('2020-01-01 16:00:00'): 270.0,
#   Timestamp('2020-01-01 17:00:00'): 260.0,
#   Timestamp('2020-01-01 18:00:00'): 252.0,
#   Timestamp('2020-01-01 19:00:00'): 257.0,
#   Timestamp('2020-01-01 20:00:00'): 271.0,
#   Timestamp('2020-01-01 21:00:00'): 269.0,
#   Timestamp('2020-01-01 22:00:00'): 281.0,
#   Timestamp('2020-01-01 23:00:00'): 298.0,
#   Timestamp('2020-01-02 00:00:00'): 285.0},
#  'WSPD': {Timestamp('2020-01-01 00:00:00'): 6.1,
#   Timestamp('2020-01-01 01:00:00'): 6.0,
#   Timestamp('2020-01-01 02:00:00'): 4.7,
#   Timestamp('2020-01-01 03:00:00'): 5.1,
#   Timestamp('2020-01-01 04:00:00'): 6.4,
#   Timestamp('2020-01-01 05:00:00'): 10.0,
#   Timestamp('2020-01-01 06:00:00'): 7.4,
#   Timestamp('2020-01-01 07:00:00'): 6.3,
#   Timestamp('2020-01-01 08:00:00'): 4.4,
#   Timestamp('2020-01-01 09:00:00'): 7.5,
#   Timestamp('2020-01-01 10:00:00'): 6.1,
#   Timestamp('2020-01-01 11:00:00'): 7.1,
#   Timestamp('2020-01-01 12:00:00'): 6.0,
#   Timestamp('2020-01-01 13:00:00'): 5.0,
#   Timestamp('2020-01-01 14:00:00'): 5.7,
#   Timestamp('2020-01-01 15:00:00'): 8.2,
#   Timestamp('2020-01-01 16:00:00'): 7.1,
#   Timestamp('2020-01-01 17:00:00'): 8.1,
#   Timestamp('2020-01-01 18:00:00'): 7.2,
#   Timestamp('2020-01-01 19:00:00'): 7.1,
#   Timestamp('2020-01-01 20:00:00'): 6.1,
#   Timestamp('2020-01-01 21:00:00'): 4.7,
#   Timestamp('2020-01-01 22:00:00'): 4.2,
#   Timestamp('2020-01-01 23:00:00'): 2.4,
#   Timestamp('2020-01-02 00:00:00'): 2.4},
#  'GST': {Timestamp('2020-01-01 00:00:00'): 6.2,
#   Timestamp('2020-01-01 01:00:00'): 6.9,
#   Timestamp('2020-01-01 02:00:00'): 5.6,
#   Timestamp('2020-01-01 03:00:00'): 6.1,
#   Timestamp('2020-01-01 04:00:00'): 7.2,
#   Timestamp('2020-01-01 05:00:00'): 11.5,
#   Timestamp('2020-01-01 06:00:00'): 8.2,
#   Timestamp('2020-01-01 07:00:00'): 7.2,
#   Timestamp('2020-01-01 08:00:00'): 5.7,
#   Timestamp('2020-01-01 09:00:00'): 9.1,
#   Timestamp('2020-01-01 10:00:00'): 7.2,
#   Timestamp('2020-01-01 11:00:00'): 8.2,
#   Timestamp('2020-01-01 12:00:00'): 7.1,
#   Timestamp('2020-01-01 13:00:00'): 5.8,
#   Timestamp('2020-01-01 14:00:00'): 6.2,
#   Timestamp('2020-01-01 15:00:00'): 9.7,
#   Timestamp('2020-01-01 16:00:00'): 7.8,
#   Timestamp('2020-01-01 17:00:00'): 8.5,
#   Timestamp('2020-01-01 18:00:00'): 8.2,
#   Timestamp('2020-01-01 19:00:00'): 7.9,
#   Timestamp('2020-01-01 20:00:00'): 6.8,
#   Timestamp('2020-01-01 21:00:00'): 5.2,
#   Timestamp('2020-01-01 22:00:00'): 4.8,
#   Timestamp('2020-01-01 23:00:00'): 2.5,
#   Timestamp('2020-01-02 00:00:00'): 2.6},
#  'WVHT': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan},
#  'DPD': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan},
#  'APD': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan},
#  'MWD': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan},
#  'PRES': {Timestamp('2020-01-01 00:00:00'): 1006.1,
#   Timestamp('2020-01-01 01:00:00'): 1006.8,
#   Timestamp('2020-01-01 02:00:00'): 1007.3,
#   Timestamp('2020-01-01 03:00:00'): 1007.8,
#   Timestamp('2020-01-01 04:00:00'): 1007.7,
#   Timestamp('2020-01-01 05:00:00'): 1007.6,
#   Timestamp('2020-01-01 06:00:00'): 1008.1,
#   Timestamp('2020-01-01 07:00:00'): 1008.7,
#   Timestamp('2020-01-01 08:00:00'): 1009.3,
#   Timestamp('2020-01-01 09:00:00'): 1009.2,
#   Timestamp('2020-01-01 10:00:00'): 1009.4,
#   Timestamp('2020-01-01 11:00:00'): 1009.8,
#   Timestamp('2020-01-01 12:00:00'): 1010.1,
#   Timestamp('2020-01-01 13:00:00'): 1010.6,
#   Timestamp('2020-01-01 14:00:00'): 1011.6,
#   Timestamp('2020-01-01 15:00:00'): 1012.1,
#   Timestamp('2020-01-01 16:00:00'): 1012.1,
#   Timestamp('2020-01-01 17:00:00'): 1011.3,
#   Timestamp('2020-01-01 18:00:00'): 1010.8,
#   Timestamp('2020-01-01 19:00:00'): 1010.5,
#   Timestamp('2020-01-01 20:00:00'): 1010.9,
#   Timestamp('2020-01-01 21:00:00'): 1011.8,
#   Timestamp('2020-01-01 22:00:00'): 1012.5,
#   Timestamp('2020-01-01 23:00:00'): 1013.2,
#   Timestamp('2020-01-02 00:00:00'): 1013.7},
#  'ATMP': {Timestamp('2020-01-01 00:00:00'): 9.5,
#   Timestamp('2020-01-01 01:00:00'): 9.3,
#   Timestamp('2020-01-01 02:00:00'): 8.7,
#   Timestamp('2020-01-01 03:00:00'): 7.8,
#   Timestamp('2020-01-01 04:00:00'): 7.1,
#   Timestamp('2020-01-01 05:00:00'): 7.0,
#   Timestamp('2020-01-01 06:00:00'): 6.5,
#   Timestamp('2020-01-01 07:00:00'): 6.2,
#   Timestamp('2020-01-01 08:00:00'): 5.9,
#   Timestamp('2020-01-01 09:00:00'): 5.9,
#   Timestamp('2020-01-01 10:00:00'): 5.7,
#   Timestamp('2020-01-01 11:00:00'): 5.9,
#   Timestamp('2020-01-01 12:00:00'): 5.8,
#   Timestamp('2020-01-01 13:00:00'): 5.7,
#   Timestamp('2020-01-01 14:00:00'): 5.7,
#   Timestamp('2020-01-01 15:00:00'): 6.1,
#   Timestamp('2020-01-01 16:00:00'): 6.5,
#   Timestamp('2020-01-01 17:00:00'): 6.8,
#   Timestamp('2020-01-01 18:00:00'): 7.2,
#   Timestamp('2020-01-01 19:00:00'): 7.6,
#   Timestamp('2020-01-01 20:00:00'): 8.1,
#   Timestamp('2020-01-01 21:00:00'): 8.7,
#   Timestamp('2020-01-01 22:00:00'): 8.6,
#   Timestamp('2020-01-01 23:00:00'): 8.1,
#   Timestamp('2020-01-02 00:00:00'): 7.7},
#  'WTMP': {Timestamp('2020-01-01 00:00:00'): 6.6,
#   Timestamp('2020-01-01 01:00:00'): 6.6,
#   Timestamp('2020-01-01 02:00:00'): 6.5,
#   Timestamp('2020-01-01 03:00:00'): 6.5,
#   Timestamp('2020-01-01 04:00:00'): 6.5,
#   Timestamp('2020-01-01 05:00:00'): 6.4,
#   Timestamp('2020-01-01 06:00:00'): 6.4,
#   Timestamp('2020-01-01 07:00:00'): 6.4,
#   Timestamp('2020-01-01 08:00:00'): 6.4,
#   Timestamp('2020-01-01 09:00:00'): 6.3,
#   Timestamp('2020-01-01 10:00:00'): 6.2,
#   Timestamp('2020-01-01 11:00:00'): 6.2,
#   Timestamp('2020-01-01 12:00:00'): 6.1,
#   Timestamp('2020-01-01 13:00:00'): 6.1,
#   Timestamp('2020-01-01 14:00:00'): 6.3,
#   Timestamp('2020-01-01 15:00:00'): 6.3,
#   Timestamp('2020-01-01 16:00:00'): 6.4,
#   Timestamp('2020-01-01 17:00:00'): 6.5,
#   Timestamp('2020-01-01 18:00:00'): 6.3,
#   Timestamp('2020-01-01 19:00:00'): 6.4,
#   Timestamp('2020-01-01 20:00:00'): 6.4,
#   Timestamp('2020-01-01 21:00:00'): 6.4,
#   Timestamp('2020-01-01 22:00:00'): 6.4,
#   Timestamp('2020-01-01 23:00:00'): 6.4,
#   Timestamp('2020-01-02 00:00:00'): 6.4},
#  'DEWP': {Timestamp('2020-01-01 00:00:00'): -0.3,
#   Timestamp('2020-01-01 01:00:00'): -0.6,
#   Timestamp('2020-01-01 02:00:00'): -1.4,
#   Timestamp('2020-01-01 03:00:00'): -2.3,
#   Timestamp('2020-01-01 04:00:00'): -2.5,
#   Timestamp('2020-01-01 05:00:00'): -2.8,
#   Timestamp('2020-01-01 06:00:00'): -2.2,
#   Timestamp('2020-01-01 07:00:00'): -3.0,
#   Timestamp('2020-01-01 08:00:00'): -2.5,
#   Timestamp('2020-01-01 09:00:00'): -3.3,
#   Timestamp('2020-01-01 10:00:00'): -3.7,
#   Timestamp('2020-01-01 11:00:00'): -4.1,
#   Timestamp('2020-01-01 12:00:00'): -4.1,
#   Timestamp('2020-01-01 13:00:00'): -4.3,
#   Timestamp('2020-01-01 14:00:00'): -4.9,
#   Timestamp('2020-01-01 15:00:00'): -6.0,
#   Timestamp('2020-01-01 16:00:00'): -5.1,
#   Timestamp('2020-01-01 17:00:00'): -6.3,
#   Timestamp('2020-01-01 18:00:00'): -5.6,
#   Timestamp('2020-01-01 19:00:00'): -6.4,
#   Timestamp('2020-01-01 20:00:00'): -5.4,
#   Timestamp('2020-01-01 21:00:00'): -4.6,
#   Timestamp('2020-01-01 22:00:00'): -5.5,
#   Timestamp('2020-01-01 23:00:00'): -7.0,
#   Timestamp('2020-01-02 00:00:00'): -8.0},
#  'VIS': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan},
#  'TIDE': {Timestamp('2020-01-01 00:00:00'): nan,
#   Timestamp('2020-01-01 01:00:00'): nan,
#   Timestamp('2020-01-01 02:00:00'): nan,
#   Timestamp('2020-01-01 03:00:00'): nan,
#   Timestamp('2020-01-01 04:00:00'): nan,
#   Timestamp('2020-01-01 05:00:00'): nan,
#   Timestamp('2020-01-01 06:00:00'): nan,
#   Timestamp('2020-01-01 07:00:00'): nan,
#   Timestamp('2020-01-01 08:00:00'): nan,
#   Timestamp('2020-01-01 09:00:00'): nan,
#   Timestamp('2020-01-01 10:00:00'): nan,
#   Timestamp('2020-01-01 11:00:00'): nan,
#   Timestamp('2020-01-01 12:00:00'): nan,
#   Timestamp('2020-01-01 13:00:00'): nan,
#   Timestamp('2020-01-01 14:00:00'): nan,
#   Timestamp('2020-01-01 15:00:00'): nan,
#   Timestamp('2020-01-01 16:00:00'): nan,
#   Timestamp('2020-01-01 17:00:00'): nan,
#   Timestamp('2020-01-01 18:00:00'): nan,
#   Timestamp('2020-01-01 19:00:00'): nan,
#   Timestamp('2020-01-01 20:00:00'): nan,
#   Timestamp('2020-01-01 21:00:00'): nan,
#   Timestamp('2020-01-01 22:00:00'): nan,
#   Timestamp('2020-01-01 23:00:00'): nan,
#   Timestamp('2020-01-02 00:00:00'): nan}}

# %% [markdown]
# ### Concluding remarks

# %% [markdown]
# The NDBC API is a living project, and is open both to community requests and code contributions.  Please feel free to submit a pull request or open an issue on the [GitHub repository](https://www.github.com/cdjellen/ndbc-api) if you have any questions or suggestions.
#
# Thank you for your time and have an excellent rest of your day, wherever in the world you are!
