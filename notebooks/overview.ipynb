# %% [markdown]
# <div align="center">
#     <h3>A Python API for the National Data Buoy Center</h3>
# </div>
#
#
# The National Oceanic and Atmospheric Association's National Data Buoy Center maintains marine monitoring and observation stations around the world[^1]. These stations report atmospheric, oceanographic, and other meterological data at regular intervals to the NDBC. Measurements are made available over HTTP through the NDBC's data service.
#
# The ndbc-api is a python library that makes this data more widely accessible.
#
# The ndbc-api is primarily built to parse whitespace-delimited oceanographic and atmospheric data distributed as text files for available time ranges, on a station-by-station basis[^2]. Measurements are typically distributed as `utf-8` encoded, station-by-station, fixed-period text files. More information on the measurements and methodology are available [on the NDBC website](https://www.ndbc.noaa.gov/docs/ndbc_web_data_guide.pdf)[^3].
#
# [^1]: https://www.ndbc.noaa.gov/
# [^2]: https://www.ndbc.noaa.gov/obs.shtml
# [^3]: https://www.ndbc.noaa.gov/docs/ndbc_web_data_guide.pdf

# %% [markdown]
# This sample notebook covers some of the core functionality of the `NdbcApi`, including usage examples for retrieving the list of stations, station metadata, station measurements, and finding the nearest station to a given location.
#
# We assume some familiarity with NDBC data buoy's, their purpose, and their data formats, but the examples help provide extra context for users new to the NDBC data service.  One important feature to consider is that not all data buoys are alike.  Some buoys provide a full suite of measurements, while others provide only a subset.  The `NdbcApi` provides methods to help users determine which measurements are available for a given station, and to retrieve those measurements.

# %% [markdown]
# ### Setup

# %% [markdown]
# These setup steps are useful when cloning the project from source and running the notebooks locally.  If you are running the notebooks in a cloud environment, you can skip these steps and just run the cells under the "API Overview" heading.

# %%
import os
import sys

# %%
os.chdir("..")
sys.path.append(os.getcwd())

# %% [markdown]
# ### API Overview

# %% [markdown]
# The API surface is exposed through the `NdbcApi` class.  The `NdbcApi` is a singleton, such that the underlying `RequestHandler` and NDBC station-level `RequestCache`s are shared between instances. Both the singleton metaclass and `RequestHandler` are implemented to reduce the likelihood of repeat requests to the NDBC's data service, and to converse NDBC resources. This is balanced by a station-level `cache_limit`, implemented as an LRU cache, which seeks to balance a respect for user resources and NDBC resources.

# %%
from ndbc_api import NdbcApi

# %%
api = NdbcApi()

# %% [markdown]
# #### Obtain a list of NDBC-maintained stations (data buoys)

# %% [markdown]
# Now that we have our `api` instance, we can begin to obtain information from the NDBC data service.
#
# We begin by retrieving a list of all data buoys, and some of their high-level metadata.

# %%
api.stations()
# Out:
#      Station     Lat      Lon  Elevation  \
# 0      13001  12.000  -23.000        0.0
# 1      13002  21.000  -23.000        0.0
# 2      13008  15.000  -38.000        0.0
# 3      13009   8.000  -38.000        0.0
# 4      14041  -8.000   55.000        0.0
# ...      ...     ...      ...        ...
# 1346   yata2  59.548 -139.733        NaN
# 1347   ygnn6  43.262  -79.064       73.0
# 1348   yktv2  37.227  -76.479        3.7
# 1349   yrsv2  37.414  -76.712       11.0
# 1350   zbqn7  33.955  -77.935        NaN
#
#                                              Name  \
# 0                                    NE Extension
# 1                                    NE Extension
# 2                                          Reggae
# 3                                         Lambada
# 4
# ...                                           ...
# 1346           9453220 - Yakutat, Yakutat Bay, AK
# 1347              Niagara Coast Guard Station, NY
# 1348  8637689 - Yorktown USCG Training Center, VA
# 1349   Taskinas Creek, Chesapeake Bay Reserve, VA
# 1350                 Zeke's Basin, North Carolina
#
#                                                   Owner  \
# 0     Prediction and Research Moored Array in the At...
# 1     Prediction and Research Moored Array in the At...
# 2     Prediction and Research Moored Array in the At...
# 3     Prediction and Research Moored Array in the At...
# 4     Research Moored Array for African-Asian-Austra...
# ...                                                 ...
# 1346                                                NOS
# 1347                          NWS WFO Buffalo, NY (BUF)
# 1348                                                NOS
# 1349         National Estuarine Research Reserve System
# 1350         National Estuarine Research Reserve System
#
#                      Program   Type  Includes Meteorology  Includes Currents  \
# 0     International Partners   buoy                 False              False
# 1     International Partners   buoy                 False              False
# 2     International Partners   buoy                 False              False
# 3     International Partners   buoy                 False              False
# 4     International Partners   buoy                 False              False
# ...                      ...    ...                   ...                ...
# 1346              NOS/CO-OPS  fixed                  True              False
# 1347           IOOS Partners  fixed                 False              False
# 1348              NOS/CO-OPS  fixed                  True              False
# 1349                   NERRS  fixed                  True              False
# 1350                   NERRS  fixed                 False              False
#
#       Includes Water Quality  DART Program
# 0                      False         False
# 1                      False         False
# 2                      False         False
# 3                      False         False
# 4                      False         False
# ...                      ...           ...
# 1346                   False         False
# 1347                   False         False
# 1348                   False         False
# 1349                   False         False
# 1350                   False         False
#
# [1351 rows x 12 columns]

# %% [markdown]
# It is important to note that the list of data buoys above is not exhaustive. The NDBC maintains a list of all active buoys [here](https://www.ndbc.noaa.gov/activestations.xml). The `get_stations` method returns a list of all active buoys maintained by the NDBC.
#
# There are additional buoys which are supported by other programs and feed in to the NDBC data service. As such, they should be supported. For an example, consider station id `APAM2`, which is maintained by the National Ocean Service, but is available under the `NdbcApi`'s `get_data` method. If you would like to see a buoy or buoy family added to the API, please open an issue on the [GitHub repository](https:///www.github.com/cdjellen//ndbc-api).

# %% [markdown]
# #### Check the API's supported data formats

# %% [markdown]
# The `NbdcApi` seeks to enable easy access to data from most common models of data buoy and oceanographic station.
#
# Data are assumed to follow common patterns based on the measurement type and the station type.  For example, a buoy that measures wind speed and direction will have a `cwind` mode, and a coastal station that measures wind speed and direction will have a `stdmet` mode.  The `NbdcApi` provides a `get_modes` method to list the available modes for a given station, and a `get_data` method to retrieve data for a given station and mode.
#
# Not all stations have support for all modes.

# %%
api.get_modes()
# Out:
# ['adcp',
#  'cwind',
#  'ocean',
#  'spec',
#  'stdmet',
#  'supl',
#  'swden',
#  'swdir',
#  'swdir2',
#  'swr1',
#  'swr2']

# %% [markdown]
# The `mode` parameter is ubiquitous in the `NdbcApi` (and of course in the upstream NDBC Data Service). It is used to specify the type of data to retrieve. As the indicators are not always intuitive, a descriptor of each mode is provided below:
#
# * `adcp`: Acoustic Doppler Current Profiler measurements, providing information about ocean currents at different depths.
# * `cwind`: Continuous winds data, offering high-frequency wind speed and direction measurements.
# * `ocean`: Oceanographic data, including water temperature, salinity, and wave measurements.
# * `spec`: Spectral wave data, providing detailed information about wave energy and direction.
# * `stdmet`: Standard meteorological data, including air temperature, pressure, wind speed, and visibility.
# * `supl`: Supplemental measurements, which can vary depending on the specific buoy and its sensors.
# * `swden`: Spectral wave density data, providing information about the distribution of wave energy across different frequencies.
# * `swdir`: Spectral wave direction data, indicating the primary direction of wave energy.
# * `swdir2`: Secondary spectral wave direction data, capturing additional wave direction information.
# * `swr1`: First-order spectral wave data, providing basic wave height and period information.
# * `swr2`: Second-order spectral wave data, offering more detailed wave measurements.
#
# These modes are based on the NDBC's data service, and while they cover much of the data they are not exhaustive. For a full list of modes, please refer to the [NDBC documentation](https://www.ndbc.noaa.gov/docs/ndbc_web_data_guide.pdf).

# %% [markdown]
# The API also now supports NetCDF4 data obtained through the [NOAA THREDDS](https://dods.ndbc.noaa.gov/thredds/catalog.html). Not all data is available through this server, but the subset which is can be obtained by passing `user_opendap=True` to the `get_modes` method.

# %%
api.get_modes(use_opendap=True)
# Out:
# ['adcp', 'cwind', 'ocean', 'pwind', 'stdmet', 'swden', 'wlevel', 'hfradar']

# %% [markdown]
# #### Find the nearest station to a location

# %% [markdown]
# In some cases, we might be interested in obtaining data from a location without a-priori knowledge of which data buoys or oceanography stations are nearby.  We can use the `get_nearest_stations` function to find the nearest stations to a given location.  This function returns the `station_id` of the nearest station to any given lat-lon location.
#
# It is important to check the metadata for that station to ensure it is close enough to meet your needs.

# %%
api.nearest_station(lat="38.88N", lon="76.43W")
# Out:
# 'tplm2'

# %% [markdown]
# We can also search for a station from floating-point longitude and latitude values.

# %%
api.nearest_station(lat=38.88, lon=-76.43)
# Out:
# 'tplm2'

# %% [markdown]
# The API also supports a `radial_search` method, which returns all stations within a given radius of a given location. The radius is specified as a floating point value, with the units argument specifying whether the radius is in miles. kilometers or nautical miles.

# %%
api.radial_search(lat="38.88N", lon="76.43W", radius=500, units="km")
# Out:
#     Station     Lat     Lon  Elevation  \
# 0     tplm2  38.899 -76.436        0.0
# 1     44063  38.963 -76.448        0.0
# 2     apam2  38.983 -76.479        1.4
# 3     cpvm2  38.995 -76.388        3.4
# 4     bslm2  38.781 -76.708        0.3
# ..      ...     ...     ...        ...
# 128   45190  43.282 -76.961       74.7
# 129   45142  42.740 -79.290      174.0
# 130   44402  39.314 -70.717        0.0
# 131   rprn6  43.263 -77.598       75.0
# 132   rcrn6  43.269 -77.626       76.7
#
#                                                   Name  \
# 0                                     Thomas Point, MD
# 1                                        Annapolis, MD
# 2                              8575512 - Annapolis, MD
# 3       8575437 - Chesapeake Bay Bridge Visibility, MD
# 4                  Jug Bay, Chesapeake Bay Reserve, MD
# ..                                                 ...
# 128                                    Sodus Point, NY
# 129                                      Port Colborne
# 130  SOUTHEAST BLOCK CANYON - 130 NM SE of Fire Isl...
# 131                          Rochester Coast Guard, NY
# 132                            9052058 - Rochester, NY
#
#                                                  Owner  \
# 0                                                 NDBC
# 1      Chesapeake Bay Interpretive Buoy System (CBIBS)
# 2                                                  NOS
# 3                                       NOAA NOS PORTS
# 4           National Estuarine Research Reserve System
# ..                                                 ...
# 128  SUNY Plattsburgh Center for Earth and Environm...
# 129              Environment and Climate Change Canada
# 130                                               NDBC
# 131                          NWS WFO Buffalo, NY (BUF)
# 132                                                NOS
#
#                        Program   Type  Includes Meteorology  \
# 0    NDBC Meteorological/Ocean  fixed                  True
# 1                IOOS Partners   buoy                  True
# 2                   NOS/CO-OPS  fixed                  True
# 3                   NOS/CO-OPS  fixed                 False
# 4                        NERRS  fixed                 False
# ..                         ...    ...                   ...
# 128              IOOS Partners   buoy                  True
# 129     International Partners   buoy                  True
# 130                    Tsunami   dart                 False
# 131              IOOS Partners  fixed                  True
# 132                 NOS/CO-OPS  fixed                  True
#
#      Includes Currents  Includes Water Quality  DART Program    distance
# 0                False                   False         False    2.177979
# 1                False                    True         False    9.369909
# 2                False                   False         False   12.225590
# 3                False                   False         False   13.307985
# 4                False                   False         False   26.506690
# ..                 ...                     ...           ...         ...
# 128              False                   False         False  492.036078
# 129              False                   False         False  492.561301
# 130              False                   False         False  495.825675
# 131              False                   False         False  497.635930
# 132              False                   False         False  498.756609
#
# [133 rows x 13 columns]

# %% [markdown]
# #### Obtain that station's metadata

# %% [markdown]
# The NDBC records some features of data buoys and oceanographic stations such as the location, station type, and elevations of various instruments.
#
# Using the `station_id` obtained above, we can query the NDBC data service for some additional details about the nearest station to `lat='38.88N', lon='76.43W'`.  This is both to verify that the nearest station is indeed close to our desired location, and to learn more about how measurements of interest are collected.

# %%
api.station(station_id="tplm2")
# Out:
# {'Sea temp depth': '1 m below MLLW',
#  'Barometer elevation': '12.2 m above mean sea level',
#  'Anemometer height': '18 m above site elevation',
#  'Air temp height': '17.4 m above site elevation',
#  'Site elevation': '0 m above mean sea level',
#  'Location': '38.899 N 76.436 W (38°53\'56" N 76°26\'9" W)',
#  'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, MARS payload',
#  'Name': 'Station TPLM2  - Thomas Point, MD'}

# %% [markdown]
# We can also obtain this metadata as a pandas DataFrame.

# %%
api.station(station_id="tplm2", as_df=True)
# Out:
#                                                                      0
# Sea temp depth                                          1 m below MLLW
# Barometer elevation                        12.2 m above mean sea level
# Anemometer height                            18 m above site elevation
# Air temp height                            17.4 m above site elevation
# Site elevation                                0 m above mean sea level
# Location                    38.899 N 76.436 W (38°53'56" N 76°26'9" W)
# Statation Type       Owned and maintained by National Data Buoy Cen...
# Name                                 Station TPLM2  - Thomas Point, MD

# %% [markdown]
# While this information provides some helpful context about the station, it does not tell us what measurements are actually collected at the station.  We learned that it is a C-MAN station, and that it is maintained by the NDBC.  In order to determine what realtime and historical measurements are available for query, we can make two additional API calls.

# %% [markdown]
# #### Obtain the realtime measurements available at that station

# %% [markdown]
# Each station, due to the variety of buoy designs and environmental factors, offers a potentially different set of available measurements.  In order to determine what realtime measurements are available for a specific station, we can use the `available_realtime` API method.

# %%
api.available_realtime(station_id="tplm2")
# Out:
# ['cwind', 'stdmet']

# %% [markdown]
# While understanding the set of currently-supported measurements is important for data retrieval, it is also useful to understand the historical measurements available at a station.  The `available_historical` method provides this data in the same format as above, indexed by year.
#
# For both realtime and historical data, the API supports returning the response as pandas DataFrame when passing the keyword argument `as_df=True` to `available_realtime` or `available_historical`.

# %% [markdown]
# #### Obtain measurements over a given time range

# %% [markdown]
# Now that we know both `stdmet` (Standard Meterological) and `cwind` (Continuous Winds) data are available for our station, we can begin to obtain these measurements using our API.
#
# We can select any time range of interest, regardless of the 45-day limit for "realtime" data before it becomes "historical" data.  The API abstracts these concerns away, and will automatically retrieve the data from the appropriate source, unifying it into a single `pd.DataFrame` or `dict` object.

# %% [markdown]
# We can begin by querying all `stdmet` data for our station `'tplm2'` for calendar-year 2020.  These dates follow the time conventions of the NDBC data service.

# %%
df_stdmet_tplm2 = api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2022-01-01',
    as_df=True
)

# %% [markdown]
# By inspecting the returned `pd.DataFrame`, we can see that some of the typical `stdmet` feautures are unavailable for this station.  If we were to pull this data directly from the NDBC data service, these missing measurements would be marked with `99.0` `999` or `999.0` values (depending on the measurement).  However, the `stdmet` data service replaces these values with `NaN` values.  This is done to make it easier to work with the data in downstream applications and analyses.

# %%
df_stdmet_tplm2.head(3).T
# Out:
# timestamp  2020-01-01 00:00:00 2020-01-01 01:00:00 2020-01-01 02:00:00
# station_id               tplm2               tplm2               tplm2
# WDIR                     188.0               273.0               286.0
# WSPD                       6.1                 6.0                 4.7
# GST                        6.2                 6.9                 5.6
# WVHT                       NaN                 NaN                 NaN
# DPD                        NaN                 NaN                 NaN
# APD                        NaN                 NaN                 NaN
# MWD                        NaN                 NaN                 NaN
# PRES                    1006.1              1006.8              1007.3
# ATMP                       9.5                 9.3                 8.7
# WTMP                       6.6                 6.6                 6.5
# DEWP                      -0.3                -0.6                -1.4
# VIS                        NaN                 NaN                 NaN
# TIDE                       NaN                 NaN                 NaN

# %%
df_stdmet_tplm2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 17280 entries, (Timestamp('2020-01-01 00:00:00'), 'tplm2') to (Timestamp('2022-01-01 00:00:00'), 'tplm2')
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WDIR    17255 non-null  float64
#  1   WSPD    17280 non-null  float64
#  2   GST     17280 non-null  float64
#  3   WVHT    0 non-null      object
#  4   DPD     0 non-null      object
#  5   APD     0 non-null      object
#  6   MWD     0 non-null      object
#  7   PRES    17278 non-null  float64
#  8   ATMP    17278 non-null  float64
#  9   WTMP    17280 non-null  float64
#  10  DEWP    14715 non-null  float64
#  11  VIS     0 non-null      object
#  12  TIDE    0 non-null      object
# dtypes: float64(7), object(6)
# memory usage: 2.4+ MB

# %% [markdown]
# In the informational view above, note that we have indexed the data by its `timestamp`, which was computed using the `'YY'`, `'MM'`, `'DD'`, `'hh'`, and `'mm'` fields typical of the NDBC data service.

# %% [markdown]
# We can also capture this data as a basic python `dict` object, which can be used to create other data structures or serialized for outside analysis or tools.

# %%
api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2020-01-02',
    as_df=False
)
# Out:
# {'stdmet': [[{'WDIR': 188,
#     'WSPD': 6.1,
#     'GST': 6.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1006.1,
#     'ATMP': 9.5,
#     'WTMP': 6.6,
#     'DEWP': -0.3,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 273,
#     'WSPD': 6.0,
#     'GST': 6.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1006.8,
#     'ATMP': 9.3,
#     'WTMP': 6.6,
#     'DEWP': -0.6,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 286,
#     'WSPD': 4.7,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1007.3,
#     'ATMP': 8.7,
#     'WTMP': 6.5,
#     'DEWP': -1.4,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 278,
#     'WSPD': 5.1,
#     'GST': 6.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1007.8,
#     'ATMP': 7.8,
#     'WTMP': 6.5,
#     'DEWP': -2.3,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 293,
#     'WSPD': 6.4,
#     'GST': 7.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1007.7,
#     'ATMP': 7.1,
#     'WTMP': 6.5,
#     'DEWP': -2.5,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 297,
#     'WSPD': 10.0,
#     'GST': 11.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1007.6,
#     'ATMP': 7.0,
#     'WTMP': 6.4,
#     'DEWP': -2.8,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 296,
#     'WSPD': 7.4,
#     'GST': 8.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1008.1,
#     'ATMP': 6.5,
#     'WTMP': 6.4,
#     'DEWP': -2.2,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 287,
#     'WSPD': 6.3,
#     'GST': 7.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1008.7,
#     'ATMP': 6.2,
#     'WTMP': 6.4,
#     'DEWP': -3.0,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 287,
#     'WSPD': 4.4,
#     'GST': 5.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1009.3,
#     'ATMP': 5.9,
#     'WTMP': 6.4,
#     'DEWP': -2.5,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 282,
#     'WSPD': 7.5,
#     'GST': 9.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1009.2,
#     'ATMP': 5.9,
#     'WTMP': 6.3,
#     'DEWP': -3.3,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 286,
#     'WSPD': 6.1,
#     'GST': 7.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1009.4,
#     'ATMP': 5.7,
#     'WTMP': 6.2,
#     'DEWP': -3.7,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 276,
#     'WSPD': 7.1,
#     'GST': 8.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1009.8,
#     'ATMP': 5.9,
#     'WTMP': 6.2,
#     'DEWP': -4.1,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 271,
#     'WSPD': 6.0,
#     'GST': 7.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1010.1,
#     'ATMP': 5.8,
#     'WTMP': 6.1,
#     'DEWP': -4.1,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 275,
#     'WSPD': 5.0,
#     'GST': 5.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1010.6,
#     'ATMP': 5.7,
#     'WTMP': 6.1,
#     'DEWP': -4.3,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 266,
#     'WSPD': 5.7,
#     'GST': 6.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1011.6,
#     'ATMP': 5.7,
#     'WTMP': 6.3,
#     'DEWP': -4.9,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 269,
#     'WSPD': 8.2,
#     'GST': 9.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1012.1,
#     'ATMP': 6.1,
#     'WTMP': 6.3,
#     'DEWP': -6.0,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 270,
#     'WSPD': 7.1,
#     'GST': 7.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1012.1,
#     'ATMP': 6.5,
#     'WTMP': 6.4,
#     'DEWP': -5.1,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 260,
#     'WSPD': 8.1,
#     'GST': 8.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1011.3,
#     'ATMP': 6.8,
#     'WTMP': 6.5,
#     'DEWP': -6.3,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 252,
#     'WSPD': 7.2,
#     'GST': 8.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1010.8,
#     'ATMP': 7.2,
#     'WTMP': 6.3,
#     'DEWP': -5.6,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 257,
#     'WSPD': 7.1,
#     'GST': 7.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1010.5,
#     'ATMP': 7.6,
#     'WTMP': 6.4,
#     'DEWP': -6.4,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 271,
#     'WSPD': 6.1,
#     'GST': 6.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1010.9,
#     'ATMP': 8.1,
#     'WTMP': 6.4,
#     'DEWP': -5.4,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 269,
#     'WSPD': 4.7,
#     'GST': 5.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1011.8,
#     'ATMP': 8.7,
#     'WTMP': 6.4,
#     'DEWP': -4.6,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 281,
#     'WSPD': 4.2,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1012.5,
#     'ATMP': 8.6,
#     'WTMP': 6.4,
#     'DEWP': -5.5,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 298,
#     'WSPD': 2.4,
#     'GST': 2.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1013.2,
#     'ATMP': 8.1,
#     'WTMP': 6.4,
#     'DEWP': -7.0,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 1, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 285,
#     'WSPD': 2.4,
#     'GST': 2.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1013.7,
#     'ATMP': 7.7,
#     'WTMP': 6.4,
#     'DEWP': -8.0,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2020, 1, 2, 0, 0),
#     'station_id': 'tplm2'}]]}

# %% [markdown]
# Some research efforts require obtaining data from the same mode across many stations, multiple modes for the same station, or multiple modes across multiple stations. These use cases are also supported by the `get_data` method. For these use cases, `station_ids` (a list of station ids) or `modes` can be specified in lieu of `station_id` or `mode`. Please use key-word arguments (specifying the parameter name directly) to leverage these features.

# %%
df_annapolis_met = api.get_data(
    station_ids=['tplm2', 'apam2', 44063, 'CPVM2'],
    modes=['stdmet'],
    start_time='2025-03-01',
    end_time='2026-03-01',
    as_df=True
)

# %% [markdown]
# The returned `pd.DataFrame` will match the format explored earlier, with one key difference. The `station_id` is now included along with the `timestamp` as a multi-index.
#
# All station ids included in `station_ids` are stored in the same long-formatted `pd.DataFrame`, and can be filtered based on the feature of interest (e.g. `'WDIR'`), the station_id (e.g. `TPLM2`), and the timestamp.
#
# The Pandas API specifications suggests using the `xs` method to filter data based on the multi-index.  This method is demonstrated below.

# %%
df_annapolis_met.xs('tplm2', level='station_id').head(3).T
# Out:
# timestamp 2025-03-01 00:00:00 2025-03-01 01:00:00 2025-03-01 02:00:00
# WDIR                    131.0               144.0               145.0
# WSPD                      7.2                12.0                11.9
# GST                       7.8                13.1                13.3
# WVHT                      NaN                 NaN                 NaN
# DPD                       NaN                 NaN                 NaN
# APD                       NaN                 NaN                 NaN
# MWD                       NaN                 NaN                 NaN
# PRES                   1008.4              1007.8              1007.1
# ATMP                      6.9                 6.2                 6.0
# WTMP                      NaN                 NaN                 NaN
# DEWP                      NaN                 NaN                 NaN
# VIS                       NaN                 NaN                 NaN
# TIDE                      NaN                 NaN                 NaN

# %% [markdown]
# #### Lightweight Environments and Polars Support

# %% [markdown]
# The `ndbc-api` is designed to be lightweight and flexible. While `pandas` and `xarray` are installed by default to ensure backward compatibility, users building lightweight applications or deploying to resource-constrained environments can safely uninstall them (`pip uninstall pandas xarray`). The core API will automatically fall back to returning data as a list of dictionaries (`as_df=False`), ensuring your application remains functional without the overhead of heavy data-science libraries.

# %% [markdown]
# For users who prefer modern, high-performance data processing, the API fully supports `polars`. You can retrieve data as a `polars.DataFrame` by passing `as_pl=True` to the `get_data` method. This provides exact parity with the `pandas` integration.

# %%
pl_stdmet_tplm2 = api.get_data(
    'tplm2',
    'stdmet',
    '2020-01-01',
    '2022-01-01',
    as_pl=True
)

# %% [markdown]
# By inspecting the returned `pl.DataFrame`, we can see the same data structure as the pandas example, but backed by Polars' lightning-fast Rust engine.

# %%
pl_stdmet_tplm2.head(3)
# Out:
# shape: (3, 15)
# ┌──────┬──────┬─────┬──────┬───┬──────┬──────┬─────────────────────┬────────────┐
# │ WDIR ┆ WSPD ┆ GST ┆ WVHT ┆ … ┆ VIS  ┆ TIDE ┆ timestamp           ┆ station_id │
# │ ---  ┆ ---  ┆ --- ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---                 ┆ ---        │
# │ i64  ┆ f64  ┆ f64 ┆ null ┆   ┆ null ┆ null ┆ datetime[μs]        ┆ str        │
# ╞══════╪══════╪═════╪══════╪═══╪══════╪══════╪═════════════════════╪════════════╡
# │ 188  ┆ 6.1  ┆ 6.2 ┆ null ┆ … ┆ null ┆ null ┆ 2020-01-01 00:00:00 ┆ tplm2      │
# │ 273  ┆ 6.0  ┆ 6.9 ┆ null ┆ … ┆ null ┆ null ┆ 2020-01-01 01:00:00 ┆ tplm2      │
# │ 286  ┆ 4.7  ┆ 5.6 ┆ null ┆ … ┆ null ┆ null ┆ 2020-01-01 02:00:00 ┆ tplm2      │
# └──────┴──────┴─────┴──────┴───┴──────┴──────┴─────────────────────┴────────────┘

# %% [markdown]
# Just like with pandas, the Polars integration supports multi-station and multi-mode requests. The resulting DataFrame will include a `station_id` column, allowing you to easily filter and aggregate across multiple data buoys.

# %%
pl_annapolis_met = api.get_data(
    station_ids=['tplm2', 'apam2', 44063, 'CPVM2'],
    modes=['stdmet'],
    start_time='2025-03-01',
    end_time='2026-03-01',
    as_pl=True
)

# %% [markdown]
# We can use Polars' expressive expression API to filter the data for a specific station, achieving the same result as the pandas `xs` multi-index selection.

# %%
import polars as pl

pl_annapolis_met.filter(pl.col('station_id') == 'tplm2').head(3)
# Out:
# shape: (3, 15)
# ┌──────┬──────┬──────┬──────┬───┬──────┬──────┬─────────────────────┬────────────┐
# │ WDIR ┆ WSPD ┆ GST  ┆ WVHT ┆ … ┆ VIS  ┆ TIDE ┆ timestamp           ┆ station_id │
# │ ---  ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---                 ┆ ---        │
# │ i64  ┆ f64  ┆ f64  ┆ f64  ┆   ┆ f64  ┆ null ┆ datetime[μs]        ┆ str        │
# ╞══════╪══════╪══════╪══════╪═══╪══════╪══════╪═════════════════════╪════════════╡
# │ 131  ┆ 7.2  ┆ 7.8  ┆ null ┆ … ┆ null ┆ null ┆ 2025-03-01 00:00:00 ┆ tplm2      │
# │ 144  ┆ 12.0 ┆ 13.1 ┆ null ┆ … ┆ null ┆ null ┆ 2025-03-01 01:00:00 ┆ tplm2      │
# │ 145  ┆ 11.9 ┆ 13.3 ┆ null ┆ … ┆ null ┆ null ┆ 2025-03-01 02:00:00 ┆ tplm2      │
# └──────┴──────┴──────┴──────┴───┴──────┴──────┴─────────────────────┴────────────┘

# %% [markdown]
# As above, can also capture this data as a basic python `dict` object. As no all stations in a given `get_data` request might have all requested `modes`, we log errors in cases where no data is found for a given `(station_id, mode)` pair. We return all data available, noting the error through api logging.

# %%
from datetime import datetime, timedelta, timezone

end_time = datetime.now(timezone.utc).strftime('%Y-%m-%d')
start_time = (datetime.now(timezone.utc) - timedelta(days=365)).strftime('%Y-%m-%d')

api.get_data(
    station_ids=['tplm2', 'apam2'],
    modes=['stdmet', 'cwind'],  # cwind is not available for 'apam2' so we will log an error and continue
    start_time=start_time,
    end_time=end_time,
    as_df=False
)
# Out:
# {'stdmet': [[{'WDIR': 147,
#     'WSPD': 10.3,
#     'GST': 11.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.5,
#     'ATMP': 27.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 9.8,
#     'GST': 10.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.3,
#     'ATMP': 27.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 164,
#     'WSPD': 8.8,
#     'GST': 9.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.8,
#     'ATMP': 27.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 171,
#     'WSPD': 8.5,
#     'GST': 9.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.5,
#     'ATMP': 27.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 167,
#     'WSPD': 8.4,
#     'GST': 9.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.4,
#     'ATMP': 26.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 166,
#     'WSPD': 8.1,
#     'GST': 8.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.2,
#     'ATMP': 26.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 172,
#     'WSPD': 7.7,
#     'GST': 8.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.0,
#     'ATMP': 25.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 175,
#     'WSPD': 6.9,
#     'GST': 8.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.6,
#     'ATMP': 25.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 181,
#     'WSPD': 6.2,
#     'GST': 7.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 25.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 185,
#     'WSPD': 6.0,
#     'GST': 6.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.8,
#     'ATMP': 24.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 179,
#     'WSPD': 4.9,
#     'GST': 5.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.8,
#     'ATMP': 24.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 198,
#     'WSPD': 4.6,
#     'GST': 5.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 24.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 203,
#     'WSPD': 2.7,
#     'GST': 3.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 25.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 202,
#     'WSPD': 1.9,
#     'GST': 2.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.4,
#     'ATMP': 26.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 170,
#     'WSPD': 2.1,
#     'GST': 2.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 26.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 150,
#     'WSPD': 4.2,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 27.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 141,
#     'WSPD': 4.9,
#     'GST': 5.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 27.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 139,
#     'WSPD': 4.6,
#     'GST': 5.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 28.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 4.3,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 29.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 5.7,
#     'GST': 5.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.7,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 144,
#     'WSPD': 5.5,
#     'GST': 5.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1014.8,
#     'ATMP': 30.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 6.0,
#     'GST': 6.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.1,
#     'ATMP': 30.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 179,
#     'WSPD': 6.1,
#     'GST': 6.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.0,
#     'ATMP': 30.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 233,
#     'WSPD': 4.2,
#     'GST': 4.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1014.9,
#     'ATMP': 30.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 25, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 233,
#     'WSPD': 6.8,
#     'GST': 7.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.5,
#     'ATMP': 30.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 243,
#     'WSPD': 6.5,
#     'GST': 7.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.8,
#     'ATMP': 28.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 266,
#     'WSPD': 5.8,
#     'GST': 6.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 29.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 58,
#     'WSPD': 2.5,
#     'GST': 2.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.1,
#     'ATMP': 28.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 331,
#     'WSPD': 2.4,
#     'GST': 2.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.4,
#     'ATMP': 28.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 316,
#     'WSPD': 2.2,
#     'GST': 2.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.3,
#     'ATMP': 27.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 277,
#     'WSPD': 3.0,
#     'GST': 3.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 27.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 285,
#     'WSPD': 3.8,
#     'GST': 4.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 27.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 298,
#     'WSPD': 2.3,
#     'GST': 2.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 26.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 292,
#     'WSPD': 2.3,
#     'GST': 2.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.5,
#     'ATMP': 26.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 302,
#     'WSPD': 2.1,
#     'GST': 2.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 26.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 309,
#     'WSPD': 2.1,
#     'GST': 2.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.5,
#     'ATMP': 26.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 10,
#     'WSPD': 5.8,
#     'GST': 6.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.0,
#     'ATMP': 27.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 8,
#     'WSPD': 6.1,
#     'GST': 6.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.3,
#     'ATMP': 26.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 360,
#     'WSPD': 4.3,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.5,
#     'ATMP': 26.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 26,
#     'WSPD': 2.7,
#     'GST': 3.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.5,
#     'ATMP': 27.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 340,
#     'WSPD': 2.8,
#     'GST': 3.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.7,
#     'ATMP': 27.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 342,
#     'WSPD': 2.7,
#     'GST': 3.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.8,
#     'ATMP': 27.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 334,
#     'WSPD': 2.2,
#     'GST': 2.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.5,
#     'ATMP': 28.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 350,
#     'WSPD': 2.0,
#     'GST': 2.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.1,
#     'ATMP': 28.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 3,
#     'WSPD': 3.3,
#     'GST': 3.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.6,
#     'ATMP': 28.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 82,
#     'WSPD': 4.3,
#     'GST': 4.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 74,
#     'WSPD': 5.9,
#     'GST': 6.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 29.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 79,
#     'WSPD': 7.2,
#     'GST': 7.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 28.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 26, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 92,
#     'WSPD': 7.1,
#     'GST': 7.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 27.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 85,
#     'WSPD': 6.5,
#     'GST': 7.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.4,
#     'ATMP': 26.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 88,
#     'WSPD': 6.3,
#     'GST': 6.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.1,
#     'ATMP': 26.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 103,
#     'WSPD': 8.0,
#     'GST': 8.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.8,
#     'ATMP': 25.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 114,
#     'WSPD': 7.9,
#     'GST': 8.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1019.1,
#     'ATMP': 25.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 122,
#     'WSPD': 8.9,
#     'GST': 10.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.6,
#     'ATMP': 26.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 118,
#     'WSPD': 7.8,
#     'GST': 8.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.2,
#     'ATMP': 26.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 110,
#     'WSPD': 5.4,
#     'GST': 6.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.6,
#     'ATMP': 26.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 104,
#     'WSPD': 4.8,
#     'GST': 5.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.2,
#     'ATMP': 26.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 128,
#     'WSPD': 4.7,
#     'GST': 5.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.2,
#     'ATMP': 26.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 97,
#     'WSPD': 3.8,
#     'GST': 4.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.2,
#     'ATMP': 25.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 108,
#     'WSPD': 3.8,
#     'GST': 4.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 25.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 139,
#     'WSPD': 4.2,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.3,
#     'ATMP': 26.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 159,
#     'WSPD': 7.2,
#     'GST': 7.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 27.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 179,
#     'WSPD': 4.6,
#     'GST': 5.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 27.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 185,
#     'WSPD': 3.1,
#     'GST': 3.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.2,
#     'ATMP': 28.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 141,
#     'WSPD': 5.5,
#     'GST': 5.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.7,
#     'ATMP': 28.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 133,
#     'WSPD': 6.6,
#     'GST': 7.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.9,
#     'ATMP': 28.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 146,
#     'WSPD': 7.7,
#     'GST': 8.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.7,
#     'ATMP': 28.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 141,
#     'WSPD': 2.5,
#     'GST': 3.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.9,
#     'ATMP': 24.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 172,
#     'WSPD': 6.0,
#     'GST': 6.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.8,
#     'ATMP': 26.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 209,
#     'WSPD': 5.9,
#     'GST': 6.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.7,
#     'ATMP': 26.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 255,
#     'WSPD': 4.8,
#     'GST': 5.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.5,
#     'ATMP': 26.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 229,
#     'WSPD': 4.9,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.9,
#     'ATMP': 26.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 27, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 221,
#     'WSPD': 4.6,
#     'GST': 5.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.4,
#     'ATMP': 26.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 199,
#     'WSPD': 4.9,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.2,
#     'ATMP': 25.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 221,
#     'WSPD': 4.4,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 25.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 223,
#     'WSPD': 4.8,
#     'GST': 5.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 25.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 221,
#     'WSPD': 4.2,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 25.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 258,
#     'WSPD': 4.0,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.3,
#     'ATMP': 25.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 229,
#     'WSPD': 2.5,
#     'GST': 3.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.4,
#     'ATMP': 25.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 281,
#     'WSPD': 4.9,
#     'GST': 5.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.9,
#     'ATMP': 25.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 293,
#     'WSPD': 4.8,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.0,
#     'ATMP': 25.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 292,
#     'WSPD': 4.3,
#     'GST': 5.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.4,
#     'ATMP': 25.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 296,
#     'WSPD': 4.4,
#     'GST': 5.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 25.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 295,
#     'WSPD': 4.1,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.3,
#     'ATMP': 24.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 316,
#     'WSPD': 5.2,
#     'GST': 5.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.8,
#     'ATMP': 26.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 339,
#     'WSPD': 5.1,
#     'GST': 5.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.5,
#     'ATMP': 26.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 354,
#     'WSPD': 4.5,
#     'GST': 5.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.4,
#     'ATMP': 27.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 358,
#     'WSPD': 5.6,
#     'GST': 6.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.5,
#     'ATMP': 27.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 7,
#     'WSPD': 3.2,
#     'GST': 3.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.6,
#     'ATMP': 28.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 41,
#     'WSPD': 2.6,
#     'GST': 2.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.5,
#     'ATMP': 28.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 96,
#     'WSPD': 1.7,
#     'GST': 1.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.0,
#     'ATMP': 29.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 96,
#     'WSPD': 2.0,
#     'GST': 2.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.5,
#     'ATMP': 30.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 115,
#     'WSPD': 2.6,
#     'GST': 2.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.7,
#     'ATMP': 30.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 131,
#     'WSPD': 4.0,
#     'GST': 4.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.3,
#     'ATMP': 30.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 148,
#     'WSPD': 2.9,
#     'GST': 3.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.2,
#     'ATMP': 30.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 152,
#     'WSPD': 3.4,
#     'GST': 3.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.2,
#     'ATMP': 30.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 28, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 148,
#     'WSPD': 2.4,
#     'GST': 2.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 170,
#     'WSPD': 2.1,
#     'GST': 2.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.1,
#     'ATMP': 29.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 191,
#     'WSPD': 2.6,
#     'GST': 2.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.6,
#     'ATMP': 29.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 238,
#     'WSPD': 1.7,
#     'GST': 1.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.7,
#     'ATMP': 28.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 265,
#     'WSPD': 1.5,
#     'GST': 1.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 28.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 235,
#     'WSPD': 0.6,
#     'GST': 0.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 28.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 57,
#     'WSPD': 0.0,
#     'GST': 0.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 28.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 197,
#     'WSPD': 0.6,
#     'GST': 0.7,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.5,
#     'ATMP': 28.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 301,
#     'WSPD': 1.6,
#     'GST': 1.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.5,
#     'ATMP': 27.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 360,
#     'WSPD': 2.6,
#     'GST': 2.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.0,
#     'ATMP': 27.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 308,
#     'WSPD': 2.3,
#     'GST': 2.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 27.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 317,
#     'WSPD': 1.8,
#     'GST': 2.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 27.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 335,
#     'WSPD': 2.4,
#     'GST': 2.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.3,
#     'ATMP': 27.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 355,
#     'WSPD': 1.4,
#     'GST': 1.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.3,
#     'ATMP': 27.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 57,
#     'WSPD': 0.0,
#     'GST': 0.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 29.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 57,
#     'WSPD': 0.0,
#     'GST': 0.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1018.1,
#     'ATMP': 29.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 57,
#     'WSPD': 0.0,
#     'GST': 0.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 30.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 108,
#     'WSPD': 1.0,
#     'GST': 1.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.7,
#     'ATMP': 31.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 108,
#     'WSPD': 1.3,
#     'GST': 1.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.4,
#     'ATMP': 31.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 69,
#     'WSPD': 1.6,
#     'GST': 1.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.0,
#     'ATMP': 31.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 107,
#     'WSPD': 1.7,
#     'GST': 1.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 31.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 133,
#     'WSPD': 2.8,
#     'GST': 3.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.5,
#     'ATMP': 31.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 137,
#     'WSPD': 1.8,
#     'GST': 1.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.5,
#     'ATMP': 31.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 160,
#     'WSPD': 2.2,
#     'GST': 2.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 31.5,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 29, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 144,
#     'WSPD': 2.2,
#     'GST': 2.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.7,
#     'ATMP': 31.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 135,
#     'WSPD': 2.1,
#     'GST': 2.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 31.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 202,
#     'WSPD': 3.0,
#     'GST': 3.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 29.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 214,
#     'WSPD': 2.8,
#     'GST': 3.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 29.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 199,
#     'WSPD': 2.9,
#     'GST': 3.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.1,
#     'ATMP': 29.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 179,
#     'WSPD': 4.6,
#     'GST': 5.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 28.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 189,
#     'WSPD': 4.8,
#     'GST': 5.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.9,
#     'ATMP': 28.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 196,
#     'WSPD': 4.3,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 27.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 210,
#     'WSPD': 2.3,
#     'GST': 2.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 27.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 242,
#     'WSPD': 3.4,
#     'GST': 4.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.6,
#     'ATMP': 27.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 238,
#     'WSPD': 3.6,
#     'GST': 4.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.5,
#     'ATMP': 27.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 239,
#     'WSPD': 4.3,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.2,
#     'ATMP': 27.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 251,
#     'WSPD': 3.2,
#     'GST': 3.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 27.4,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 256,
#     'WSPD': 2.2,
#     'GST': 2.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 28.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 57,
#     'WSPD': 0.0,
#     'GST': 0.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.9,
#     'ATMP': 31.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 131,
#     'WSPD': 3.9,
#     'GST': 4.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.5,
#     'ATMP': 28.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 132,
#     'WSPD': 3.1,
#     'GST': 3.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.7,
#     'ATMP': 29.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 4.2,
#     'GST': 4.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1017.3,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 137,
#     'WSPD': 4.2,
#     'GST': 4.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.8,
#     'ATMP': 30.3,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 141,
#     'WSPD': 5.1,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.2,
#     'ATMP': 30.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 5.2,
#     'GST': 5.6,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.8,
#     'ATMP': 30.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 132,
#     'WSPD': 4.9,
#     'GST': 5.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.1,
#     'ATMP': 30.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 149,
#     'WSPD': 5.1,
#     'GST': 5.5,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.1,
#     'ATMP': 30.8,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 156,
#     'WSPD': 4.9,
#     'GST': 5.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.1,
#     'ATMP': 30.6,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 30, 23, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 155,
#     'WSPD': 6.5,
#     'GST': 7.0,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.2,
#     'ATMP': 30.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 0, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 152,
#     'WSPD': 7.9,
#     'GST': 8.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.2,
#     'ATMP': 30.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 1, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 154,
#     'WSPD': 5.9,
#     'GST': 6.9,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.9,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 2, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 159,
#     'WSPD': 6.8,
#     'GST': 7.3,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1016.2,
#     'ATMP': 29.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 3, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 156,
#     'WSPD': 6.9,
#     'GST': 7.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.9,
#     'ATMP': 29.1,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 4, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 155,
#     'WSPD': 6.8,
#     'GST': 7.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.4,
#     'ATMP': 28.9,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 5, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 167,
#     'WSPD': 6.0,
#     'GST': 6.4,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.5,
#     'ATMP': 28.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 6, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 174,
#     'WSPD': 6.6,
#     'GST': 7.1,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.1,
#     'ATMP': 28.2,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 190,
#     'WSPD': 5.3,
#     'GST': 6.2,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1015.0,
#     'ATMP': 28.0,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 189,
#     'WSPD': 4.0,
#     'GST': 4.8,
#     'WVHT': None,
#     'DPD': None,
#     'APD': None,
#     'MWD': None,
#     'PRES': 1014.8,
#     'ATMP': 27.7,
#     'WTMP': None,
#     'DEWP': None,
#     'VIS': None,
#     'TIDE': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 189,
# ...
#     'station_id': 'tplm2'},
#    {'WDIR': 170,
#     'WSPD': 5.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 173,
#     'WSPD': 5.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 173,
#     'WSPD': 5.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 176,
#     'WSPD': 5.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 187,
#     'WSPD': 5.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 7, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 190,
#     'WSPD': 5.0,
#     'GDR': 170,
#     'GST': 7.2,
#     'GTIME': 700,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 186,
#     'WSPD': 5.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 188,
#     'WSPD': 4.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 185,
#     'WSPD': 4.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 188,
#     'WSPD': 3.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 186,
#     'WSPD': 3.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 8, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 187,
#     'WSPD': 3.9,
#     'GDR': 190,
#     'GST': 6.1,
#     'GTIME': 802,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 184,
#     'WSPD': 3.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 179,
#     'WSPD': 3.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 181,
#     'WSPD': 2.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 183,
#     'WSPD': 2.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 197,
#     'WSPD': 1.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 9, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 187,
#     'WSPD': 2.0,
#     'GDR': 183,
#     'GST': 4.9,
#     'GTIME': 901,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 171,
#     'WSPD': 1.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 166,
#     'WSPD': 2.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 172,
#     'WSPD': 2.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 153,
#     'WSPD': 2.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 173,
#     'WSPD': 2.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 10, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 173,
#     'WSPD': 2.6,
#     'GDR': 170,
#     'GST': 3.1,
#     'GTIME': 1051,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 166,
#     'WSPD': 2.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 157,
#     'WSPD': 3.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 161,
#     'WSPD': 2.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 166,
#     'WSPD': 3.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 164,
#     'WSPD': 3.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 11, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 164,
#     'WSPD': 4.1,
#     'GDR': 159,
#     'GST': 5.0,
#     'GTIME': 1145,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 156,
#     'WSPD': 4.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 160,
#     'WSPD': 4.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 162,
#     'WSPD': 3.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 164,
#     'WSPD': 3.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 175,
#     'WSPD': 3.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 12, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 171,
#     'WSPD': 2.7,
#     'GDR': 151,
#     'GST': 4.8,
#     'GTIME': 1210,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 162,
#     'WSPD': 2.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 160,
#     'WSPD': 3.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 3.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 154,
#     'WSPD': 3.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 146,
#     'WSPD': 3.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 13, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 147,
#     'WSPD': 3.9,
#     'GDR': 147,
#     'GST': 4.6,
#     'GTIME': 1356,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 4.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 151,
#     'WSPD': 4.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 144,
#     'WSPD': 4.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 4.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 142,
#     'WSPD': 4.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 14, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 146,
#     'WSPD': 4.3,
#     'GDR': 143,
#     'GST': 5.3,
#     'GTIME': 1451,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 142,
#     'WSPD': 4.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 4.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 141,
#     'WSPD': 4.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 4.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 5.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 15, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 5.5,
#     'GDR': 141,
#     'GST': 6.0,
#     'GTIME': 1556,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 5.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 5.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 5.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 6.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 142,
#     'WSPD': 6.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 16, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 142,
#     'WSPD': 6.5,
#     'GDR': 142,
#     'GST': 7.8,
#     'GTIME': 1659,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 7.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 7.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 142,
#     'WSPD': 9.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 139,
#     'WSPD': 9.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 9.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 17, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 140,
#     'WSPD': 10.1,
#     'GDR': 140,
#     'GST': 11.7,
#     'GTIME': 1757,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 138,
#     'WSPD': 9.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 134,
#     'WSPD': 8.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 136,
#     'WSPD': 9.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 137,
#     'WSPD': 10.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 136,
#     'WSPD': 9.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 18, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 149,
#     'WSPD': 7.8,
#     'GDR': 137,
#     'GST': 12.0,
#     'GTIME': 1831,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 261,
#     'WSPD': 10.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 233,
#     'WSPD': 9.9,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 220,
#     'WSPD': 4.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 134,
#     'WSPD': 5.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 138,
#     'WSPD': 9.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 19, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 150,
#     'WSPD': 8.8,
#     'GDR': 268,
#     'GST': 14.6,
#     'GTIME': 1906,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 133,
#     'WSPD': 5.5,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 143,
#     'WSPD': 4.0,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 162,
#     'WSPD': 3.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 180,
#     'WSPD': 3.8,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 184,
#     'WSPD': 4.7,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 20, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 183,
#     'WSPD': 4.2,
#     'GDR': 145,
#     'GST': 7.7,
#     'GTIME': 2000,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 221,
#     'WSPD': 3.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 206,
#     'WSPD': 3.3,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 229,
#     'WSPD': 2.4,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 30),
#     'station_id': 'tplm2'},
#    {'WDIR': 276,
#     'WSPD': 3.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 40),
#     'station_id': 'tplm2'},
#    {'WDIR': 310,
#     'WSPD': 5.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 21, 50),
#     'station_id': 'tplm2'},
#    {'WDIR': 331,
#     'WSPD': 9.7,
#     'GDR': 330,
#     'GST': 11.8,
#     'GTIME': 2154,
#     'timestamp': datetime.datetime(2025, 7, 31, 22, 0),
#     'station_id': 'tplm2'},
#    {'WDIR': 349,
#     'WSPD': 12.1,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 22, 10),
#     'station_id': 'tplm2'},
#    {'WDIR': 350,
#     'WSPD': 12.2,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 22, 20),
#     'station_id': 'tplm2'},
#    {'WDIR': 355,
#     'WSPD': 10.6,
#     'GDR': None,
#     'GST': None,
#     'GTIME': None,
#     'timestamp': datetime.datetime(2025, 7, 31, 22, 30),
#     'station_id': 'tplm2'},
#    ...]]}

# %% [markdown]
# ##### Native `NetCDF4` data through the NDBC DODS/THREDDS data service

# %% [markdown]
# The NDBC API now supports retrieving data across stations and modes in the native `DODS NetCDF4` [format](https://dods.ndbc.noaa.gov/) provided by [THREDDS](https://dods.ndbc.noaa.gov/thredds/catalog/data/catalog.html). This data is retrieved from the DODS server through HTTPS, with the resulting data matching the quality-controlled records as closely as possible.
#
# Data retrieval through THREDDS is controlled using the `as_xarray_dataset` argument (defaults to `False`).
#
# As with the standard usage of the `get_data` method, the `start_time`, `end_time`, and `cols` arguments can be used to efficiently filter data during retrieval.

# %%
ds = api.get_data(station_ids=["tplm2"], modes=["stdmet"], start_time="2019-06-01", end_time="2024-06-01", as_xarray_dataset=True)

# %%
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:                  (time: 43515, latitude: 1, longitude: 1)
# Coordinates:
#   * time                     (time) datetime64[ns] 348kB 2019-06-01 ... 2024-...
#   * latitude                 (latitude) float32 4B 38.9
#   * longitude                (longitude) float32 4B -76.44
# Data variables: (12/13)
#     wind_dir                 (time, latitude, longitude) float64 348kB 92.0 ....
#     wind_spd                 (time, latitude, longitude) float32 174kB 1.8 .....
#     gust                     (time, latitude, longitude) float32 174kB 1.9 .....
#     wave_height              (time, latitude, longitude) float32 174kB nan .....
#     dominant_wpd             (time, latitude, longitude) timedelta64[ns] 348kB ...
#     average_wpd              (time, latitude, longitude) timedelta64[ns] 348kB ...
#     ...                       ...
#     air_pressure             (time, latitude, longitude) float32 174kB 1.01e+...
#     air_temperature          (time, latitude, longitude) float32 174kB 25.5 ....
#     sea_surface_temperature  (time, latitude, longitude) float32 174kB 23.7 ....
#     dewpt_temperature        (time, latitude, longitude) float32 174kB 17.2 ....
#     visibility               (time, latitude, longitude) float32 174kB nan .....
#     water_level              (time, latitude, longitude) float32 174kB nan .....
# Attributes:
#     institution:  NOAA National Data Buoy Center and Participators in Data As...
#     url:          http://dods.ndbc.noaa.gov
#     quality:      Automated QC checks with manual editing and comprehensive m...
#     conventions:  COARDS
#     station:      tplm2
#     comment:      Thomas Point, MD
#     location:     38.899 N 76.436 W

# %% [markdown]
# The returned `netCDF4.Dataset` objects are ephemeral, but can be explicitly saved to disk by passing the Dataset and a file path to the API's `save_netcdf_dataset` method, as below:

# %%
api.save_xarray_dataset(ds, "test.nc")

# %% [markdown]
# The `save_xarray_dataset` method will save the dataset to disk in the specified file path. The file path should include the desired file name and extension (e.g. `my_dataset.nc`).
#
# The method also supports keyword arguments, which are passed to the underlying `xarray.Dataset`'s `to_netcdf` method. This allows for additional control over the saved dataset, such as compression level, encoding, and other options. For example, to use the `h5netcdf` backend when saving the dataset, one could specify `kwargs={'engine': 'h5netcdf'}`.

# %% [markdown]
# ##### High-frequency Radar Data as `NetCDF4` through the NDBC DODS/THREDDS data service

# %% [markdown]
# High-frequency radar data is also available through the THREDDS data service, albeit stored and structured differently than standard NDBC data. The `NdbcApi`s `get_data` method supports retrieving this data by passing the `mode='hfradar'` argument, and one ore more `station_id`s in the form `{identifier}_{resolution}` (e.g. `'uswc_1km'` for 1 kilometer resolution data covering the United States West Coast). The `use_opendap` argument should also be set to `True` to explicitly request data from the THREDDS server.
#
# When these arguments are specified, the API will return data in the `NetCDF4` format, which can be easily accessed and manipulated using libraries such as `xarray`.

# %%
from datetime import datetime, timedelta, timezone

end_time = (datetime.now(timezone.utc) - timedelta(days=1)).strftime('%Y-%m-%d')
start_time = (datetime.now(timezone.utc) - timedelta(days=2)).strftime('%Y-%m-%d')

# %%
ds_hfradar = api.get_data(
  mode="hfradar",
  station_id="uswc_1km",
  start_time=start_time,
  end_time=end_time,  # this returns 1 hour of data
  use_opendap=True,
)

# %%
ds_hfradar
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*

# %% [markdown]
# ### Logging Configuration

# %% [markdown]
# The API supports logging configuration at initialization through two arguments:
#
# ```python3
# api = NdbcApi(
#     logging_level=logging.WARNING,  # one of logging.DEBUG, logging.INFO, logging.WARNING, or logging.ERROR
#     filename=None,  # an optional filepath at which to write log files
#     ...
# )
# ```
#
# At any time, the logging can be updated by calling `api.configure_logging(level=..., filename=...)` as shown below.

# %%
import logging

api.configure_logging(level=logging.DEBUG)

# %%
api.get_data(
    station_ids=['tplm2', 'apam2'],
    modes=['stdmet', 'cwind'],  # cwind is not available for 'apam2' so we will log an error and continue
    start_time='2025-03-01',
    end_time='2026-03-01',
)
# Out:
# [DEBUG]: {'message': "`get_data` called with arguments: {'self': <ndbc_api.ndbc_api.NdbcApi object at 0x791df7f23a30>, 'station_id': None, 'mode': None, 'start_time': '2025-03-01', 'end_time': '2026-03-01', 'use_timestamp': True, 'as_df': True, 'as_pl': False, 'cols': None, 'station_ids': ['tplm2', 'apam2'], 'modes': ['stdmet', 'cwind'], 'as_xarray_dataset': False, 'use_opendap': None}"}
# {'message': "`get_data` called with arguments: {'self': "
#             '<ndbc_api.ndbc_api.NdbcApi object at 0x791df7f23a30>, '
#             "'station_id': None, 'mode': None, 'start_time': '2025-03-01', "
#             "'end_time': '2026-03-01', 'use_timestamp': True, 'as_df': True, "
#             "'as_pl': False, 'cols': None, 'station_ids': ['tplm2', 'apam2'], "
#             "'modes': ['stdmet', 'cwind'], 'as_xarray_dataset': False, "
#             "'use_opendap': None}"}
# [INFO]: {'message': "Processing request for station_ids ['tplm2', 'apam2'] and modes ['stdmet', 'cwind']"}
# {'message': "Processing request for station_ids ['tplm2', 'apam2'] and modes "
#             "['stdmet', 'cwind']"}
# [INFO]: {'message': 'Handling 2 requests for station tplm2.'}
# {'message': 'Handling 2 requests for station tplm2.'}
# [INFO]: {'message': 'Handling 2 requests for station apam2.'}
# {'message': 'Handling 2 requests for station apam2.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Found station tplm2 in cache.'}
# {'message': 'Found station tplm2 in cache.', 'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Found station apam2 in cache.'}
# {'message': 'Found station apam2 in cache.', 'station_id': 'apam2'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2h2025.txt.gz&dir=data/historical/stdmet/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2h2025.txt.gz&dir=data/historical/stdmet/.'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2h2025.txt.gz&dir=data/historical/stdmet/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2h2025.txt.gz&dir=data/historical/stdmet/.'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2h2025.txt.gz&dir=data/historical/stdmet/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2h2025.txt.gz&dir=data/historical/stdmet/ '
#             'already in cache.'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2h2025.txt.gz&dir=data/historical/stdmet/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2h2025.txt.gz&dir=data/historical/stdmet/ '
#             'already in cache.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Found station tplm2 in cache.'}
# {'message': 'Found station tplm2 in cache.', 'station_id': 'tplm2'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/stdmet/Mar/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/stdmet/Mar/.'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Found station apam2 in cache.'}
# {'message': 'Found station apam2 in cache.', 'station_id': 'apam2'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/stdmet/Mar/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/stdmet/Mar/ '
#             'already in cache.'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/stdmet/Mar/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/stdmet/Mar/.'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/stdmet/Mar/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/stdmet/Mar/ '
#             'already in cache.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Successfully processed request for station_id tplm2'}
# {'message': 'Successfully processed request for station_id tplm2',
#  'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Successfully processed request for station_id apam2'}
# {'message': 'Successfully processed request for station_id apam2',
#  'station_id': 'apam2'}
# [INFO]: {'message': 'Handling 2 requests for station tplm2.'}
# {'message': 'Handling 2 requests for station tplm2.'}
# [INFO]: {'message': 'Handling 2 requests for station apam2.'}
# {'message': 'Handling 2 requests for station apam2.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Found station tplm2 in cache.'}
# {'message': 'Found station tplm2 in cache.', 'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Found station apam2 in cache.'}
# {'message': 'Found station apam2 in cache.', 'station_id': 'apam2'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2c2025.txt.gz&dir=data/historical/cwind/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2c2025.txt.gz&dir=data/historical/cwind/.'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2c2025.txt.gz&dir=data/historical/cwind/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2c2025.txt.gz&dir=data/historical/cwind/.'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2c2025.txt.gz&dir=data/historical/cwind/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm2c2025.txt.gz&dir=data/historical/cwind/ '
#             'already in cache.'}
# [DEBUG]: {'message': 'Request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2c2025.txt.gz&dir=data/historical/cwind/ already in cache.'}
# {'message': 'Request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam2c2025.txt.gz&dir=data/historical/cwind/ '
#             'already in cache.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Found station tplm2 in cache.'}
# {'message': 'Found station tplm2 in cache.', 'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Found station apam2 in cache.'}
# {'message': 'Found station apam2 in cache.', 'station_id': 'apam2'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/.'}
# [DEBUG]: {'message': 'Handling request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/.'}
# {'message': 'Handling request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/.'}
# [DEBUG]: {'message': 'Adding request https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/ to cache.'}
# {'message': 'Adding request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/ '
#             'to cache.'}
# [DEBUG]: {'message': 'Adding request https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/ to cache.'}
# {'message': 'Adding request '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/ '
#             'to cache.'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'GET: https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/', 'extra_data': {'headers': {}}}
# {'extra_data': {'headers': {}},
#  'message': 'GET: '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=tplm232026.txt.gz&dir=data/cwind/Mar/',
#  'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'GET: https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/', 'extra_data': {'headers': {}}}
# {'extra_data': {'headers': {}},
#  'message': 'GET: '
#             'https://www.ndbc.noaa.gov/view_text_file.php?filename=apam232026.txt.gz&dir=data/cwind/Mar/',
#  'station_id': 'apam2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Response status: 404'}
# {'message': 'Response status: 404', 'station_id': 'apam2'}
# [DEBUG]: {'station_id': 'apam2', 'message': 'Successfully processed request for station_id apam2'}
# {'message': 'Successfully processed request for station_id apam2',
#  'station_id': 'apam2'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Response status: 200'}
# {'message': 'Response status: 200', 'station_id': 'tplm2'}
# [DEBUG]: {'station_id': 'tplm2', 'message': 'Successfully processed request for station_id tplm2'}
# {'message': 'Successfully processed request for station_id tplm2',
#  'station_id': 'tplm2'}
# [INFO]: {'message': 'Finished processing request.'}
# {'message': 'Finished processing request.'}
#                                  WDIR  WSPD  GST  WVHT  DPD  APD  MWD    PRES  \
# timestamp           station_id
# 2025-03-01 00:00:00 apam2       155.0   1.4  3.3   NaN  NaN  NaN  NaN  1007.2
#                     tplm2       131.0   7.2  7.8   NaN  NaN  NaN  NaN  1008.4
# 2025-03-01 00:06:00 apam2       142.0   1.3  2.6   NaN  NaN  NaN  NaN  1007.3
# 2025-03-01 00:10:00 tplm2       139.0   6.4  NaN   NaN  NaN  NaN  NaN     NaN
# 2025-03-01 00:12:00 apam2       137.0   2.0  2.8   NaN  NaN  NaN  NaN  1007.3
# ...                               ...   ...  ...   ...  ...  ...  ...     ...
# 2026-02-28 23:30:00 tplm2       206.0   4.8  NaN   NaN  NaN  NaN  NaN     NaN
# 2026-02-28 23:40:00 tplm2       182.0   2.9  NaN   NaN  NaN  NaN  NaN     NaN
# 2026-02-28 23:50:00 tplm2       181.0   2.8  NaN   NaN  NaN  NaN  NaN     NaN
# 2026-03-01 00:00:00 apam2       133.0   1.5  1.7   NaN  NaN  NaN  NaN  1016.5
#                     tplm2       175.0   4.1  4.5   NaN  NaN  NaN  NaN  1017.9
#
#                                 ATMP  WTMP  DEWP  VIS  TIDE    GDR   GTIME
# timestamp           station_id
# 2025-03-01 00:00:00 apam2        8.6   6.8   NaN  NaN   NaN    NaN     NaN
#                     tplm2        6.9   NaN   NaN  NaN   NaN  134.0  2350.0
# 2025-03-01 00:06:00 apam2        8.6   6.9   NaN  NaN   NaN    NaN     NaN
# 2025-03-01 00:10:00 tplm2        NaN   NaN   NaN  NaN   NaN    NaN     NaN
# 2025-03-01 00:12:00 apam2        8.6   6.9   NaN  NaN   NaN    NaN     NaN
# ...                              ...   ...   ...  ...   ...    ...     ...
# 2026-02-28 23:30:00 tplm2        NaN   NaN   NaN  NaN   NaN    NaN     NaN
# 2026-02-28 23:40:00 tplm2        NaN   NaN   NaN  NaN   NaN    NaN     NaN
# 2026-02-28 23:50:00 tplm2        NaN   NaN   NaN  NaN   NaN    NaN     NaN
# 2026-03-01 00:00:00 apam2        7.7   3.8   NaN  NaN   NaN    NaN     NaN
#                     tplm2        6.8   NaN   2.6  NaN   NaN  209.0  2325.0
#
# [103581 rows x 15 columns]

# %% [markdown]
# ### Concluding remarks

# %% [markdown]
# The NDBC API is a living project, and is open both to community requests and code contributions.  Please feel free to submit a pull request or open an issue on the [GitHub repository](https://www.github.com/cdjellen/ndbc-api) if you have any questions or suggestions.
#
# Thank you for your time and have an excellent rest of your day, wherever in the world you are!
